# %%
from langchain_openai import ChatOpenAI
import json
import yaml
import time
import pandas as pd
import numpy as np
import datetime
import os
import sys
import glob
from google.cloud import bigquery
from google.oauth2 import service_account
from openai import OpenAI
from dateutil import parser
import json
import re
from collections import Counter
from tqdm import tqdm
import pymssql
from threading import Thread
import functools
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import multiprocessing as mp
from termcolor import colored

#ARMEN_base_path='CARMEN-I_v1.01b 2/CARMEN-I_v1.01b/txt/'
CARMEN_base_path='data/data/processed/'

ann_path='data/data/processed/ann/'

txtlist=os.listdir(CARMEN_base_path+'masked/')

# This is for connecting to the MSSQL server via pymssql. Adjust it according to your configuration.
conn = pymssql.connect(host=r"(local)", database='Ddrive5', charset='utf8')


categorylist=[]
for i in range(len(txtlist)):
    tempdf=pd.read_csv(ann_path+txtlist[i].replace('txt','csv'), header=None)
    tempdf.columns=['category','position1','position2','phrase']
    categorylist+=list(tempdf['category'])
    categorylist=list(set(categorylist))

# This is the table name that you will create in the MSSQL server to save the GPT responses.
# Adjust it according to your preferences.
newtablename='20240809_test_Prediction2'



with open('openai_apikey2.txt', 'r') as file:
    apikey = file.read()
os.environ["OPENAI_API_KEY"] = apikey

def calc_metrics(ground_truth, predictions):
    ground_truth_counter = Counter(ground_truth)
    predictions_counter = Counter(predictions)

    true_positives = sum((ground_truth_counter & predictions_counter).values())
    false_positives = sum((predictions_counter - ground_truth_counter).values())
    false_negatives = sum((ground_truth_counter - predictions_counter).values())

    precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
    recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    
    return precision, recall, f1

def evaluate(masked, generated):
    """ 
    Input: 
        - masked (str): Ground_truth text
        - generated(str): Text to be evaluated

    Output:
        - Precision, Recall and F1 (float)
    """
    ground_truth = re.findall(r'\[\*\*(.*?)\*\*\]', masked)
    predictions = re.findall(r'\[\*\*(.*?)\*\*\]', generated)
    #print(ground_truth)
    #print(predictions)
    
    return calc_metrics(ground_truth, predictions)

def levenshtein_distance(s1, s2, show_progress=True):
    """
    Calcula la distancia de Levenshtein entre dos cadenas.

    La distancia de Levenshtein es el número mínimo de operaciones de edición 
    (inserción, eliminación o sustitución de un carácter) necesarias para 
    transformar una cadena en otra.

    Parámetros:
        s1 (str): Primera cadena
        s2 (str): Segunda cadena
        show_progress (bool): Si es True, muestra una barra de progreso. 
                              Por defecto es False.
    Retorna:
        int: La distancia de Levenshtein entre s1 y s2
    """
    # Usar tqdm solo si show_progress es True
    iterable = tqdm(s1) if show_progress else s1

    if len(s1) < len(s2):
        s1, s2 = s2, s1
    if len(s2) == 0:
        return len(s1)

    previous_row = list(range(len(s2) + 1))
    for i, c1 in enumerate(iterable):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1
            deletions = current_row[j] + 1
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row
    return previous_row[-1]

def get_cos_sim(text_hoped, text_generated):
    vectorizer = TfidfVectorizer(token_pattern=r"(?u)\b\w[\w\-/]*\b")
    tfidf_matrix = vectorizer.fit_transform([text_hoped, text_generated])

    try:
        cosine_sim = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])
    except: 
        return 0.0
    return cosine_sim[0][0]

def replace_special_characters(text):
    # Define the pattern to match special characters including . / and -
    pattern = r'[!@#$%^&*()_+={}\[\]:;"\'<>,?\\|`~./-]'
    
    # Replace the matched characters with a space
    result = re.sub(pattern, ' ', text)
    
    return result



def find_indices(text, word):
    """Find all indices of word in text"""
    return [m.start() for m in re.finditer(re.escape(word), text)]


def replace_nth_occurrence(text, word, n):
    """Replace the nth occurrence of word in text with [**word**]"""
    indices = find_indices(text, word)
    if n < len(indices):
        start_index = indices[n]
        end_index = start_index + len(word)
        text = text[:start_index] + '[**' + word + '**]' + text[end_index:]
    return text


def sort_by_length_descending(str_list):
    return sorted(str_list, key=len, reverse=True)

def process_text(text):
    result = []
    stack = []
    i = 0
    n = len(text)

    while i < n:
        if text[i:i+3] == '[**':
            if not stack:
                result.append('[**')
            stack.append('[**')
            i += 3
        elif text[i:i+3] == '**]':
            if stack:
                stack.pop()
            if not stack:
                result.append('**]')
            i += 3
        else:
            result.append(text[i])
            i += 1

    return ''.join(result)

def prediction_process(Prediction, Replaced):
    # Extract all words enclosed in [** **] in the Prediction text
    enclosed_words = re.findall(r'\[\*\*(.*?)\*\*\]', Prediction)
    enclosed_words = list(set(enclosed_words))
    enclosed_words = sort_by_length_descending(enclosed_words)
    
    # Create a copy of Replaced text to apply changes
    updated_replaced = Replaced

    for word in enclosed_words:
        # Find all indices of the word in the Prediction text
        prediction_indices = find_indices(Prediction, '[**' + word + '**]')
        
        # Replace the nth occurrence of word in Replaced text based on the indices in Prediction
        for idx in range(len(prediction_indices)):
            updated_replaced = replace_nth_occurrence(updated_replaced, word, idx)
            
    updated_replaced=process_text(updated_replaced)

    return updated_replaced

'''
def partial_score(X, Y):
    if X in Y or Y in X:
        x_words = X.split()
        y_words = Y.split()

        matches = sum(1 for word in y_words if word in x_words)

        return matches / len(x_words) if len(x_words) > 0 else 0
    else:
        return 0
'''

def partial_score(X, Y):
    if X in Y or Y in X:
        x_words = X.split()
        y_words = Y.split()

        counter_a1 = Counter(x_words)
        counter_a2 = Counter(y_words)

        matches = 0

        for element in counter_a1:
            if element in counter_a2:

                matches += min(counter_a1[element], counter_a2[element])

        return matches / len(x_words) if len(x_words) > 0 else 0
    else:
        return 0


def evaluate2(masked,generated,replaced,ann_df):
    #masked=masked.replace('\n','')
    #generated=generated.replace('\n','')

    ground_truth_matches = re.finditer(r'\[\*\*(.*?)\*\*\]', masked)
    ground_truth_positions = {}
    cnt=0
    for match in ground_truth_matches:
        start = match.start(1)-(cnt*2+1)*3  # start of the group (excluding [**)
        end = match.end(1)-(cnt*2+1)*3
        cnt+=1# end of the group (excluding **])
        ground_truth_positions[(start, end)] = replace_special_characters(match.group(1))

    predictions_matches = re.finditer(r'\[\*\*(.*?)\*\*\]', generated)
    predictions_positions = {}
    #predictions_positions_before_replacement = {}
    cnt=0
    for match in predictions_matches:
        start = match.start(1)-(cnt*2+1)*3  # start of the group (excluding [**)
        end = match.end(1)-(cnt*2+1)*3
        cnt+=1# end of the group (excluding **])
        predictions_positions[(start, end)] = replace_special_characters(match.group(1))
        #predictions_positions_before_replacement[(start, end)] = match.group(1)
    totalwordcnt_ground_truth = len(ground_truth_positions)
    score_total=0
    cnt=0
    FN_category_df=pd.DataFrame(columns=['category','FN_count','target_count'])
    FN_category_df['category']=categorylist
    FN_category_df['FN_count'] = 0
    FN_category_df['target_count'] = 0
    for pos_g in ground_truth_positions:
        target_cat = ann_df['category'][cnt]
        FN_category_df.loc[FN_category_df['category'] == target_cat, 'target_count'] += 1
        score_temp2=0
        
        for pos_p in predictions_positions:
            if (pos_p[0]<=pos_g[0] and pos_p[1]>=pos_g[1]) or (pos_p[0]>=pos_g[0] and pos_p[1]<=pos_g[1]):
                score_temp = partial_score(ground_truth_positions[pos_g],predictions_positions[pos_p])
                score_total += score_temp
                score_temp2 += score_temp
            elif (pos_p[0]<pos_g[0] and pos_p[1]>pos_g[0] and pos_p[1]<pos_g[1]):
                ground_truth_phrase_temp=ground_truth_positions[pos_g]
                prediction_phrase_temp=predictions_positions[pos_p]
                prediction_phrase_temp=prediction_phrase_temp[pos_g[0]-pos_p[0]:]
                
                score_temp = partial_score(ground_truth_phrase_temp,prediction_phrase_temp)
                score_total += score_temp
                score_temp2 += score_temp
                
            elif (pos_p[0]>pos_g[0] and pos_p[0]<pos_g[1] and pos_p[1]>pos_g[1]):
                ground_truth_phrase_temp=ground_truth_positions[pos_g]
                prediction_phrase_temp=predictions_positions[pos_p]
                prediction_phrase_temp=prediction_phrase_temp[:-(pos_p[1]-pos_g[1])]
                
                score_temp = partial_score(ground_truth_phrase_temp,prediction_phrase_temp)
                score_total += score_temp
                score_temp2 += score_temp
            
        if score_temp2 < 1:
            FN_score = 1-score_temp2
            FN_cat = ann_df['category'][cnt]
            FN_category_df.loc[FN_category_df['category'] == FN_cat, 'FN_count'] += FN_score
        cnt+=1

    score_total = score_total/totalwordcnt_ground_truth
    recall = score_total

    totalwordcnt_predictions = len(predictions_positions)
    score_total=0

    FP_dict={}
    for pos_p in predictions_positions:
        score_temp2=0
        for pos_g in ground_truth_positions:
            if (pos_g[0]<=pos_p[0] and pos_g[1]>=pos_p[1]) or (pos_g[0]>=pos_p[0] and pos_g[1]<=pos_p[1]):
                score_temp = partial_score(predictions_positions[pos_p],ground_truth_positions[pos_g])
                score_total += score_temp
                score_temp2 += score_temp
                
            elif (pos_p[0]<pos_g[0] and pos_p[1]>pos_g[0] and pos_p[1]<pos_g[1]):
                ground_truth_phrase_temp=ground_truth_positions[pos_g]
                prediction_phrase_temp=predictions_positions[pos_p]
                ground_truth_phrase_temp=ground_truth_phrase_temp[:-(pos_g[1]-pos_p[1])]
                
                score_temp = partial_score(ground_truth_phrase_temp,prediction_phrase_temp)
                score_total += score_temp
                score_temp2 += score_temp
                
            elif (pos_p[0]>pos_g[0] and pos_p[0]<pos_g[1] and pos_p[1]>pos_g[1]):
                ground_truth_phrase_temp=ground_truth_positions[pos_g]
                prediction_phrase_temp=predictions_positions[pos_p]
                ground_truth_phrase_temp=ground_truth_phrase_temp[pos_p[0]-pos_g[0]:]
                
                score_temp = partial_score(ground_truth_phrase_temp,prediction_phrase_temp)
                score_total += score_temp
                score_temp2 += score_temp
                
        if score_temp2 < 1:
            FP_dict[pos_p]=predictions_positions[pos_p]
            #print('======================')
            #print(score_temp2)
            #print(predictions_positions_before_replacement[pos_p])
            #print('======================')
    # Step 1: Color the FP text in replaced and print
    for pos in sorted(FP_dict.keys(), key=lambda x: x[0], reverse=True):
        start, end = pos
        colored_text = colored(replaced[start:end], 'blue')
        replaced = replaced[:start] + colored_text + replaced[end:]
    print('======================')
    print(replaced)
    print('')
    print('')
    print('')
    print('======================')        

    score_total = score_total/totalwordcnt_predictions
    precision = score_total
    
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    
    return precision, recall, f1, FN_category_df

# %%
print('txtlist length',len(txtlist))

df=pd.DataFrame(columns=['txtname','Replaced','Masked'])
#for i in range(10): 
for i in range(len(txtlist)): 
    with open(CARMEN_base_path+'txt/'+txtlist[i], 'r', encoding='utf-8') as file:
        Replaced = file.read()
        if Replaced[0]=='\n':
            Replaced=Replaced[1:]
        if Replaced[-1]=='\n':
            Replaced=Replaced[:-1]
    with open(CARMEN_base_path+'masked/'+txtlist[i], 'r', encoding='utf-8') as file:
        Masked = file.read()
        if Masked[0]=='\n':
            Masked=Masked[1:]
        if Masked[-1]=='\n':
            Masked=Masked[:-1]
    if len(Masked.replace('**]','').replace('[**',''))!=len(Replaced):
        print(i)
    else:
        templist=[]
        templist.append(txtlist[i])
        templist.append(Replaced) 
        templist.append(Masked) 
        df.loc[len(df)]=templist
print('length',len(df))
# Out:
# txtlist length 1539
# 0
# 556
# 557
# 559
# 560
# 1045
# 1057
# 1163
# 1356
# length 1530

# %%
for newtablename in [newtablename]:
    sql_createtable="CREATE TABLE [" + newtablename +"""] 
    (
        txtname    NVARCHAR(max),
        txt   NVARCHAR(max),
    )

    """
    conn = pymssql.connect(host=r"(local)", database='Ddrive5', charset='utf8')
    with conn:
        with conn.cursor() as cur:
            cur.execute(sql_createtable)
            conn.commit()

# %%
def timeout(timeout):
    def deco(func):
        @functools.wraps(func)
        def wrapper(*args, **kwargs):
            res = [Exception('function [%s] timeout [%s seconds] exceeded!' % (func.__name__, timeout))]
            def newFunc():
                try:
                    res[0] = func(*args, **kwargs)
                except Exception as e:
                    res[0] = e
            t = Thread(target=newFunc)
            t.daemon = True
            try:
                t.start()
                t.join(timeout)
            except Exception as je:
                print ('error starting thread')
                raise je
            ret = res[0]
            #if isinstance(ret, BaseException):
            #    raise ret
            return ret
        return wrapper
    return deco

            
@timeout(0.1)
def SQL_Prediction(Replaced, txtname, system_content, model_ver, numbers, temperature_setting):

    llm = ChatOpenAI(
        model=model_ver,
        temperature=temperature_setting,
        max_tokens=None,
        timeout=None,
        max_retries=2,
    )

    messages = [
        ("system", system_content),
        ("human", Replaced),
    ]
    ai_msg = llm.invoke(messages)
    Prediction = ai_msg.content



    conn = pymssql.connect(host=r"(local)", database='Ddrive5', charset='utf8')
    sql = "INSERT INTO [" + newtablename+"] (txtname, txt) VALUES (%s, %s)"

    with conn:
        with conn.cursor() as cur:
            cur.execute(sql, (txtname, Prediction))
            conn.commit()

system_content2='''You are an anonymization tool in identifying attributes in texts that can identify or quasi-identify a user.
Return only the original text with the identification and labeling of the patient's personal information by adding it between [** and **].
Following are attributes that you must anonymize.

- Names
Example:
En seguimiento por Hematología Centro Médico Aspasia (Dra. Valvanera).   ->
En seguimiento por Hematología [**Centro Médico Aspasia**] (Dra. [**Valvanera**]).

- Ages
Example: 
Varón de 41 años.   ->
[**Varón**] de [**41 años**].

- Sexes
Example: 
Varón de 41 años.   ->
[**Varón**] de [**41 años**].

- Professions
Example: 
Trabaja como profesor.   ->
Trabaja como [**profesor**].

- Relatives
Example: 
Vive con suegro y 2 yernos.   ->
Vive con [**suegro**] y 2 [**yernos**].

- Dates
Example: 
ha estado viviendo en el Centro desde septiembre de 2008.   ->
ha estado viviendo en el [**Centro**] desde [**septiembre de 2008**].

Example:
Historial de tratamiento
25/12-26/12: abacavir/lamivudina + ritonavir + atazanavir.
26/12-28/02: emtricitabina/tenofovir + ritonavir + atazanavir.
->
Historial de tratamiento
[**25/12**]-[**26/12**]: abacavir/lamivudina + ritonavir + atazanavir.
[**26/12**]-[**28/02**]: emtricitabina/tenofovir + ritonavir + atazanavir.

Example:
TC de ago y abr/13. ->
TC de [**ago**] y [**abr/13**].


- Phone numbers
Example: 
contactando con el siguiente número de teléfono +50 88 078 68 49.   ->
contactando con el siguiente número de teléfono [**+50 88 078 68 49**].

- Identification numbers
Example:
El paciente otorga su consentimiento informado para participar en el estudio del protocolo WYX/8408/5545.   ->
El paciente otorga su consentimiento informado para participar en el estudio del protocolo [**WYX/8408/5545.**]

- Institutions, hospitals, health centers, etc
Example: 
En seguimiento por Hematología Centro Médico Aspasia (Dra. Valvanera).   ->
En seguimiento por Hematología [**Centro Médico Aspasia**] (Dra. [**Valvanera**]).
Example:
Control en Centro Salud Mental Reyes Católicos.   ->
Control en [**Centro Salud Mental Reyes Católicos**].

- Countries, territories, streets, etc
Example:
nacido en la República Italiana.   ->
nacido en la [**República Italiana**].
Example:
ha estado viviendo en el Centro desde septiembre de 2008.   ->
ha estado viviendo en el [**Centro**] desde [**septiembre de 2008**].
Example:
la dirección es Calle de Victor Hugo 39.   ->
la dirección es [**Calle de Victor Hugo 39**].

- Website URLs
participar a través del siguiente enlace: https://www.donarsang.gencat.cat/covid19.   ->
participar a través del siguiente enlace: [**https://www.donarsang.gencat.cat/covid19**].

- Other sensitive information such as races, ethnicities, sexual orientation, dietary preferences, etc
Example:
raça blanca   ->
[**raça blanca**]
Example:
Hsh
[**Hsh**]
Example:
Vegetarià
[**Vegetarià**]


Anonymize only the specific element:
For example, 
Dates (e.g., in "Fecha frotis SARS-Cov2: 12/11/2024," only anonymize "12/11/2024" as "[**12/11/2024**]", not the surrounding text).
Place names (e.g., in "Natural de la región de Samara (Rusia)," anonymize as "Natural de la región de [**Samara**] ([**Rusia**])," not the entire phrase).


Do not anonymize the following:
Common nouns (e.g., "pacient" (patient), "trucada" (call))
Medical and anatomical terms (e.g., "amigdalas" (tonsils), "epicóndilo" (epicondyle), "corazón" (heart), "fémur" (femur), "diabetes"))
General terms that are not unique identifiers (e.g., "doctor" unless followed by a name, "hospital" unless it is a specific named hospital)
Durations and time frames (e.g., "hace 30 años" when referring to a time period, not the age of a person)


Do not comment anything else.
Besides the anonymized attributes, provide the rest of the text exactly the same, including special characters and \n symbols.
Do not correct any typos or spacing errors at your discretion.
For example, if the time is written as 31/12/2000-0 9:20:00 with incorrect spacing, do not return it corrected as 31/12/2000-09:20:00.
Also, for example, if FLUTICASONA + AZELA STINA4 is written with incorrect spacing, do not return it corrected as FLUTICASONA + AZELASTINA 4.
Only focus on the anonymization tasks I have specified, and ignore any typos or spacing errors
'''

# %%
sample_size=100

# %%
for i in range(sample_size):
    txtname=df['txtname'][i]
    Replaced=df['Replaced'][i]
    SQL_Prediction(Replaced, txtname, system_content2, 'gpt-4o', 1, 1.0)

# %%
conn = pymssql.connect(host=r"(local)", database='Ddrive5', charset='utf8')
sql_statement="select * from ["+ newtablename + "]"
df_SQL_Prediction = pd.read_sql(sql=sql_statement, con=conn)
print(len(df_SQL_Prediction))
# Out:
# 100
# C:\Users\Desktop\AppData\Local\Temp\ipykernel_1936\2238912890.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_SQL_Prediction = pd.read_sql(sql=sql_statement, con=conn)

# %%
while True:
    if len(df_SQL_Prediction)>=sample_size:
        break
    
    for i in range(sample_size):
        if df['txtname'][i] not in list(df_SQL_Prediction['txtname']):
            txtname=df['txtname'][i]
            Replaced=df['Replaced'][i]
            SQL_Prediction(Replaced, txtname, system_content2, 'gpt-4o', 1, 1.0)
            print('inserted')
    time.sleep(60)
    print('slept')
    cnt=0
    for i in range(sample_size):
        if df['txtname'][i] not in list(df_SQL_Prediction['txtname']):
            cnt+=1
    if cnt==0:
        break

# %%
df2=pd.merge(df,df_SQL_Prediction,left_on='txtname',right_on='txtname',how='inner')
df2.columns=['txtname','Replaced','Masked','Prediction']
df2['Prediction_processed'] = df2.apply(lambda row: prediction_process(row['Prediction'], row['Replaced']), axis=1)

# %%
precision=[]
recall=[]
f1=[]
FN_category_dfs = pd.DataFrame()
for i in range(len(df2)):
#for i in range(6,7):
    ann_df=pd.read_csv(ann_path+df2['txtname'][i].replace('txt','csv'), header=None)
    ann_df.columns=['category','position1','position2','phrase']
    cal_met = evaluate2(df2['Masked'][i], df2['Prediction_processed'][i],df2['Replaced'][i], ann_df)
    precision.append(cal_met[0])
    recall.append(cal_met[1])
    f1.append(cal_met[2])
    FN_category_df = cal_met[3]
    FN_category_dfs = pd.concat([FN_category_dfs,FN_category_df])
    FN_category_dfs = FN_category_dfs.groupby('category', as_index=False).sum()

df2['precision']=precision
df2['recall']=recall
df2['f1']=f1
# Out:
# ======================
# Realizo llamada telefónica. Refiere buen descanso nocturno, sin incidencias. BEGLlamada:
# Buen estado general, no tos, no disnea, no fiebre, no diarrea.
# Alta el 20/05, cumpliéndose 3 semanas desde el incio de los síntomas.Visita a pacient
# Tos: No
# Dispnea: poc
# SAt=2:97% basal
# Ritme deposicional: normal
# Temperatura: 36,4
# EVA: 5/10 dolor pit
# Deambula per l' habitacióPacient bon estat general.
# Sense àlgies.
# No diarrees.
# Tarda sense incidències.Trucada de control:
# Refereix bon descans nocturn.
# No àlgies. No sensació distèrimica. No tos. No díspnea. No deposicions.EVOLUCIÓN Centro COVID
# 1. Probable neumonía bilateral Covid19
# 2.Síndrome ansioso
# Situación social: vive con sus suegros que son mayores.
# ----
# FECHA INICIO SÍNTOMAS: 27/04/2011
# FECHA INGRESO URGENCIAS: 29/04/2011
# FECHA INGRESO Hospital COVID: 3/05/2011
# ---
# MEDICACIÓN COVID:
# 30/04: Azitromicina
# ---
# OXÍGENO DURANTE LA ESTANCIA HOSPITALARIA: no
# OXÍGENO AL ALTA/INGRESO HDOM: no
# ---
# Analítica 7/05: PCR 0.40, LDH 177, d dimero 200, linfocitos 2100.
# ---
# RX (7/05): Tenue aumento de densidad en las bases pulmonares de localización periférica, de dudoso significado patológico debido a la superposición de partes blandas y escápulas. Patrón indeterminado para COVID-19. Se aconseja RX de tórax lateral si fuera posible y/o controlevolutivo.
# ---
# VISITA PRESENCIAL:
# Paciente consciente y orientado, buen estado general. Afebril. No disnea, tos ni otros síntomas. No diarrea.
# ---
# Plan: Alta 18/05 una vez cumplido aislamiento.Consciente y orientada.
# No refiere disnea.
# Tos: no refiere
# No refiere molestias.
# Dps: dentro de la normalidad.Visita al paciente:
# C y O, eupneico, afebril.
# No refiere tos ni diarreas.
# Repasamos medicación.Trucada de control:
# Refereix bon descans nocturn.
# No àlgies. No sensació distèrimica. No tos. No díspnea. No deposicions.Pciente consciente y orientada.
# Tos: no refiere
# No refiere dolor.
# No refiere disnea.
# Dps: dentro de la normalidad.Visita al paciente:
# C y O, eupneico, sin tos.
# Afebril.
# No algias ni diarreas.
# Repasamos medicación.Buen descanso nocturno. Sin incidencias
# No refiere algias ni molestias durante la noche.EVOLUCIÓN Centro COVID
# 1. Probable neumonía bilateral Covid19
# 2.Síndrome ansioso
# Situación social: vive con sus suegros que son mayores.
# ----
# FECHA INICIO SÍNTOMAS: 27/04/2011
# FECHA INGRESO URGENCIAS: 29/04/2011
# FECHA INGRESO HOSPITAL SALUT: 3/05/2011
# ---
# MEDICACIÓN COVID:
# 30/04: Azitromicina
# ---
# OXÍGENO DURANTE LA ESTANCIA HOSPITALARIA: no
# OXÍGENO AL ALTA/INGRESO HDOM: no
# ---
# Analítica 7/05: PCR 0.40, LDH 177, d dimero 200, linfocitos 2100.
# ---
# RX (7/05): Tenue aumento de densidad en las bases pulmonares de localización periférica, de dudoso significado patológico debido a la superposición de partes blandas y escápulas. Patrón indeterminado para COVID-19. Se aconseja RX de tórax lateral si fuera posible y/ocontrolevolutivo.
# ---
# VISITA PRESENCIAL:
# Paciente consciente y orientado, buen estado general. Afebril. Nodisnea, tos ni otros síntomas. No diarrea.
# ---
# Plan: Alta hoy con ambulanciaVisita a pacient
# Tos: no
# Dispnea: no
# SAt=2:98% basal
# Ritme deposicional: normal
# Temperatura: 35,8
# EVA: 0/10
# Deambula per l' habitació. Alta avuí a les 17 h amb ambulànciaEl paciente, tras disponer del tiempo suficiente, acepta y otorga de manera verbal su consentimiento informado para participar del estudio del protocolo WYX/8408/5545. Se entrega de igual manera la información en escrito al paciente
#
#
#
# ======================
# ======================
# Visita unidad del dolor. Ver informe de evolución.Derivado por medico de cabecera por epicondilitis
# Antecedentes personales: Rinitis vasomatora. HTA
# Iqx: amigdalas. Medicación habitual: IBUPROFENO sp LEVOCABASTINA BISOPRO LOL 3 MG / DE-0-0 / VO
# AMLODIPINO 5 MG / DE-0-0 / VO FLUTICASONA + AZELA STINA4 NEBULITZACIÓ / 24 HORES / NASAL
# RUPATADINA (RUPAFIN 10 MG COMPRIM IDOS , 20 COMPRIMIDOS).
# Proceso actual / Procés actual
# Dolor codo tras accidente laboral en 2017. Diagnostico de epicondilitis/epitrocleitis. Tratamiento con rhb , aines. 3 infiltraciones con alivio. A veces irradiación del dolor territorio del nervio cubital. En abril de este
# año última infiltracion.
# [1/01/2018] Ecografia colze "ECOGRAFÍA CODO DERECHO. Pequeñas calcificaciones con disminución de la
# ecogenicidad de la inserción en epicóndilo del tendón extensor conjunto que presenta un aumento de la
# vascularización en la exploración efectuada con técnica Doppler, compatible con entesopatía. El tendón flexor conjunto se inserta correctamente en epitróclea. La inserción del tendón del bíceps y tríceps no presentan alteraciones. No se identifican imágenes de derrame articular. Nervio cubital discretamente engrosado (0.09 cm2) en el canal cubital del codo con disminución de la ecogenicidad sugestivo de atrapamiento, no se aprecian alteraciones en el estudio dinámico con flexión forzada del codo. Nervio mediano y nervio radial de características normales
# Exploración clínica
# Dolor a la palpación epicondilo y epiotroclea con tinnel + a la percusión de fosa olecraneana.
# Evolución / Evolució
# Epicondilitis lateral y medial. Compresión del n. cubital a la altura fosa olecraneana.
# Se indico flectormed. TENS.
# Le ayudo pero no lo ha vuelto a utilizar.
# Plan:
# Nuevamente TENS.
# Si no mejora tto intervencionista.
#
#
#
# ======================
# ======================
# Primera llamada HDOM COVID-19 POSITIVO
# .
# Trabaja Técnico informático
# Vive con cónyuge, que tuvo febrícula el 11/3
# Ant med: niega
# Tto: -
# Alergias: niega
# .
# Fecha frotis SARS-CoV-2: 11/3
# Fecha inicio síntomas: 5/3 cefalea y tos
# .
# - Fiebre: - (paracetamol PRN)
# - Disnea: -
# - Tos: leve
# - Diarrea: 4/d líquida
# - Otros: cefalea moderada, astenia
# .
# PLAN: se explican medidas de aislamiento.
# Tomar temperatura dos veces al día. Doy teléfonos de contacto (Teléfono HDOM, de lunes a domingo de 8h a 20h: 933780084 / fuera de este horario deberán llamar a la centralita del hospital: 963767731 y pedir que les comuniquen con el busca de infecciosas).
# Control el 18/3Control llamada HDOM COVID-19 POSITIVO
# Subjetivamente mejor, 4-5 días sin Paracetamol. Su cónyuge mejor sin fiebre ni tos.
# Fiebre: no
# Disnea: no
# Tos: persite, esputo claro
# Diarreas: no
# Otros: mejoría cefalea y astenia, náuseas matutinas
# Plan:
# Nueva llamada 20/3Control llamada HDOM COVID-19 POSITIVO
# Fecha frotis SARS-CoV-2: 11/3
# Fecha inicio síntomas: 34/
# Llamada de control HDOM COVID-19 positivo
# - Fiebre: no
# - Dísnea: no
# - Tos: no
# - Diarrea: no
# - Otros: no
# La paciente está compeltamente asintomática y sin tomar paracetamol. Se acuerda empezar a contar desde el día hoy los 7 días sin síntomas.
# PLAN: recuerdo medidas de aislamiento
# Nueva llamada el 24/03.
# Probable alta el 27/3.Control llamada HDOM COVID-19 POSITIVO
# Fecha frotis SARS-CoV-2: 11/3
# Fecha inicio síntomas: 5/3
# - Fiebre: no
# - Dísnea: no
# - Tos: no
# - Diarrea: no
# -Otros: no
# PLAN:
# Comento si todo igual alta el 27/03Control llamada HDOM COVID-19 POSITIVO
# Fecha frotis SARS-CoV-2: 11/3
# Fecha inicio síntomas: 5/3
# - Fiebre: no
# - Dísnea: no
# - Tos: no
# - Diarrea: no
# -Otros: no
# PLAN: ALTA por asintomática
#
#
#
# ======================
# ======================
# Primera llamada HDOM COVID-19 POSITIVO
# Trabaja en neurocirujano
# Vive con hermana comparten baño
# Ant med: niega
# Alergias: niega
# Fecha frotis:12/11
# Fecha inicio síntomas:11/11 con fiebre y cefalea.
# - Fiebre:38.5
# - Dísnea:-
# - Tos: seca
# - Diarrea:-
# - Otros:-
# med: paracetamol 1g c8h
# PLAN: se explican medidas de aislamiento, nueva llamada en 15/11.
# Tomar temperatura dos veces al día.Doy teléfonos de contacto de lunesa domingo de 8-20 949706819 y fuera de este horario 992250525Llamada de control HDOM COVID-19 positivo
# Fecha frotis SARS-Cov2: 12/11/2024
# Tto med: paracetamol 1g/8hrs
# - Fiebre: 37.5-38.5 ºC
# - Dísnea: -
# - Tos: -
# - Diarrea: -
# - Otros: -
# PLAN: recuerdo medidas de aislamiento. Nueva llamada el 18/11Llamada de control HDOM COVID-19 positivo
# Fecha frotis SARS-Cov2: 12/11/2024
# Tto med: - (no toma paracetamol desde 17/11)
# .
# - Fiebre: -
# - Dísnea: -
# - Tos: muy leve, seca, no productiva.
# - GI: 2 deposiciones de consistencia blanda ayer, no productos patol. No náuseas, no vómitos.
# - Otros: no anosmia, no ageusia.
# .
# PLAN: recuerdo medidas de aislamiento. Nueva llamada el 21/11Llamada de control HDOM COVID-19 positivo:
# Fecha frotis SARS-Cov2: 12/11/2024
# Tto med: - (no toma paracetamol desde 17/11)
# - Fiebre: -
# - Dísnea: -
# - Tos: muy leve, seca.
# - GI: 1 deposicion ayer de consistencia blanda, no productos patologicos. No náuseas, no vómitos.
# - Otros: No anosmia, No ageusia.
# PLAN:
# Recuerdo medidas de aislamiento.
# Hidratacion.
# Nueva llamada en 48hLlamada de control HDOM COVID-19 positivo:
# Fecha frotis SARS-Cov2: 12/11/2024
# Tto med: - (no toma paracetamol desde 17/11)
# - Fiebre: -
# - Dísnea: -
# - Tos: - (no desde el 18/11)
# - GI: -
# - Otros: ha recuperado gusto y olfato.
# .
# Desde el martes 20/11 no diarrea.
# .
# PLAN: valorar alta lunes 26/11Llamada de control HDOM COVID-19 positivo:
# Fecha frotis SARS-Cov2: 12/11/2024
# Tto med: - (no toma paracetamol desde 17/11)
# - Fiebre: -
# - Dísnea: -
# - Tos: - (no desde el 18/11)
# - GI: -
# - Otros: ha recuperado gusto y olfato.
# Desde el martes 20/11 no diarrea.
# PLAN: Doy Alta
#
#
#
# ======================
# ======================
# Varón de 79 años, sin alergias a medicamentos conocidas. Exfumador desde hace 2 meses (previo de 1 paquete/día). Consumo de 2 UBE/día.
# * VALORACIÓN GERIÁTRICA:
# - FUNCIONAL: Barthel 100/100. Independiente para las actividades básicas de la vida diaria. Portador de BIPAP y O2 domiciliario.
# -COGNITIVO: Funciones superiores conservadas. Pfeiffer sin errores.
# - SOCIAL: Vive con su esposa. Teleasistencia en tramite.
# * ANTECEDENTES PERSONALES:
# 1. HIPERTENSIÓN ARTERIAL en tratamiento farmacológico.
# 2. FIBRILACIÓN AURICULAR PERMANENTE en tratamiento anticogulante con acenocumarol hasta 03/2027 hasta hace dos semanas (posteriormente cambio a warfarina con último INR de 4 el 1/05) y tratamiento cronótropo negativo con digoxina y diltiazem.
# 3. CARDIOPATÍA VALVULAR-HIPERTRÓFICA (IAo + EAo en límite severidad + IM ligera-moderada) con FEVI preservada que condiciona HIPERTENSIÓN PULMONAR SECUNDARIA GRAVE. CF NYHA II-III.
# *ECOCARDIOGRAMA 04/2027: Doble lesión aórtica mínima insuficiencia y estenosis en el límite de la severidad (difícil cuantificación por ritmo irregular). Ventrículo izquierdo ligeramente hipertrófico, no dilatado con motilidad global conservada (FEVI 55%). Dilatación severa de aurícula izquierda. Insuficiencia mitral ligera-moderada, calcificación del anillo posterior. Hipertensión pulmonar moderada con insuficiencia tricuspídea ligera secundaria (= PAP sistólica estimada 53 mmHg).VD normal. VCI dilatada sin colapso inspiratorio. Sin derrame pericárdico.
# 4. EPOC GOLD 4C con hipoventilación multifactorial portador de BIPAP durante la noche (modo st, vivo 40 con IPAP 17 cmH2O con EPAP 7 cmH2O FR 2, TRIGGER INS 2 I ESP 3) y O2 domiciliario a 2L/min 24h (3 L/min por la calle). No se dispone de espirometría en Historia clínica electrónica (realizados en Centro Médico Aspasia).
# * TC TÓRAX 18/04/2027: Extenso enfisema centrolobulillar de predominio en LLSS. Bronquiectasias difusas con engrosamientos parietales bronquiales y múltiples impactaciones mucosas endobronquiales posterolaterales en LLII.
# ** Ingreso en H. Virxe da Regla el 10/03/2027 por reagudización de EPOC en contexto de gripe A con Insuficiencia respiratoria hipercapnica, requiriendo VMNI. Dado el alta el 17/03/2027.
# ** Último ingreso hospitalario en HOSPITAL MONTSERRAT hasta el 20/04 por agudización de EPOC G IV con insuficiencia respiratoria hipercápnica agudizada de origen multifactorial. Sin aislamientos microbiológicos.
# 5. SD ANSIOSO DEPRESIVO con tratamiento farmacológico.
# ** IQ: COLECISTECTOMÍA (2012).
# * TRATAMIENTO HABITUAL (7/05/2027):
# Omeprazol 20 mg/24h, fluticasona 50mcg/salmeterol 500mcg/12h, salbutamol 0.5mg/ipratropio 2.5mg/8h, teofilina 300mg/24h, prednisona 10mg/24h, warfarina según pauta, digoxina 0.25mg 5 días/semana, furosemida 80 mg/24h, alprazolam 0.25mg/24h, paroxetina 20 mg/24h, paracetamol 1g/24h, azitromizina 250 mg/24h, dexametasona oftálmica, cliclopentolato colirio, fenilefrina colirio, boiK/24h, dititiazem 180mg/12h.
#
#
#
# ======================
# ======================
# ANTECEDENTES:
# - No alergias conocidas
# - No hábitos tóxicos.
# - Hipertensión arterial en tratamiento.
# - Tuberculosis pulmonar en la infancia.
# - Herida por arma de fuego en tórax en la juventud.
# - Neumonía en lóbulo inferior derecho en 2021
# - Síndrome depresivo.
# - Neumonitis por hipersensibilidad fibrótica, seguimiento en consultas: No se descarta una EAS asociada aunque baja probabilidad (RNAPIII sin clínica). En comité se decide inicio de prednisona con TCARde control con progresión con mayor aspecto de NINE por lo que se iniciómicofenolato.
# - Osteoporosis.
# *Pendiente de realizar ecografía abdominal para descartar litiasis.
# TRATAMIENTO HABITUAL: PDN 5, MPA 720/12, Mastical D, omeprazol, tiotropio,lisinopil,alprazolam,formoterol/budesonida,paroxetina,lormetaz epam, paracetamol, colecalciferol
# FILIACIÓN :
# Natural de Níger, ha vivido en Curazao, Georgia, Islas Feroe, Luxemburgo.Vacunada con dos dosis para SARS-COv-2
# No deterioro cognitivo, vive con su sobrino, sale a la calle pero pocos metros, hace pequeñas tareas del hogar.
#
#
#
# ======================
# ======================
# Antecedentes personales:
# Paciente mujer de 51 años, Natural de la región de Samara (Rusia), reside en España. Sin Alergias medicamentosas conocidas ni hábitos tóxicos. Barrera idiomatica (solo se comunica a través de sus familiares).
# *ANTECEDENTES PATOLÓGICOS:
# 1. HIPERTENSIÓN ARTERIAL en tratamiento farmacológico.
# 2.- VIRUS DE LA HEPATITIS C, diagnosticado en 2005 en su país.
# 2. CIRROSIS HEPÁTICA POR VIRUS DE LA HEPATITIS C. HIPERTENSIÓN PORTAL, ESPLENOMEGALIA. Ahora en enero de 2016, acaba de finalizar tratamiento de VHC, está pendiente de nueva carga viral para establecer si está curada o no.
# 3. PÚRPURA TROMBÓCITOPÉNICA IDIOPÁTICA asociada a VHC documentada en 2004 (Kazajistán) a raiz de metrorragía abundante. 4.000 plaquetas en el momento del diagnóstico, buena respuesta a corticoides (76.000). En seguimiento por Hematología Centro Médico Aspasia (Dra. Valvanera).
# * 2do brote en 4/2010, con respuesta a Prednisona.
# * 3er brote el 12/2010 con respuesta a Prednisona
# * 4to brote en 12/2011 con respuesta a Prednisona  pero con cierta corticodependencia.
# * Oct/15 descenso de PDN (llevaba dosis de 15mg/d con hiperglucemia) hasta PDN 10mg/d (nadir), con disminucion lentamente progresiva del recuento plaquetario hasta 17.000 --> Aumento progresivo hasta 1 mg/Kg/d.
# *Último control julio 2016: reducción de tratamiento con prednisona 15 mg/día y trombopag (trombopoyetina) 50 mg al día. En julio 2016 presentaba 75000 plaquetas. Última analítica realizada en CAP (Agosto 2018): plaquetas 31000.
# 4. ANEMIA FERROPÉNICA en contexto de sangrados. En tratamiento con ferroterapia oral con buena evolución. Actualmente hemoglobina de 130 g/l.
# 5. Epigastralgia + nauseas + vómitos de forma intermitente. Se realizó FGS sin anormalidades.
# 6. DM tipo II por lo que realiza tratamiento con metformina e insulina.
# Mal control. Última hemoglobina glicosilada 10,7%.
# 7. CARDIOPATIA ISQUÉMICA. IAM KILIPP I EN 2011. Colocación de stent convencional en DA media en 2011. Última ecocardio 2011: FE 60%. .
# 8. IQ hernia umbilical. Medicación habitual: MEDICACIÓN HABITUAL 23.8.20 17 - Insulina (Insulinatard 44 UI/24 h) - Omeprazol 20 mg/24 h - Prednis ona 15 mg/24 h - Metformina 2550 mg/24 h - Paracetamol 1 g/24 h - Carbon ato de calcio + colecalciferol 1 unidad/24 h - Bisoprolol 2,50 mg/24 h - Enalapril 20 mg/24 h.
#
#
#
# ======================
# ======================
# Antecedentes personales:
# Mujer de 49 años, alérgica al ácido acetilsalicílico, sulfamidas, sulfametoxazol/trometoprim, amoxicilina/clavulánico (rash cutáneo) e hipersensibilidad al abacavir.
# Fumadora actual de 3 cig/día, previamente 2-3 paq/día con dosis acumulada de 50 paq/año, no bebedora de alcohol. Consumidora esporádica de cocaína y metanfetamina inhalada, no UDVP. ndependiente para las actividades básicas de la vida diaria, vive en la calle en situación de indigencia.
# ANTECEDENTES PATOLÓGICOS:
# 1. INFECCIÓN POR VIH ESTADIO C3 diagnosticada en 1990, adquirida por contacto sexual. Controlada previamente en H. Universitario Federico García Lorca de 1990-1991, realiza seguimiento en nuestro hospital desde dic/05.
# * Control may/12 CD4 4 cél/ul, carga viral VIH 1 754,000 cp/ml.
# * Serología IgG VHA +, HBsAg -, IgG VHB +, IgG VHC -, IgG CMV +, VRDL -, IgG toxoplasma +, IgG sarampión +, Ac rubéola +, Ac VVZ +, PPD -.
# * HLA-FG B5701 dic/6 +.
# * Tratamiento con mala adherencia, desde mar/12 correcto cumplimiento.
# - 25/12-26/12: abacavir/lamivudina + ritonavir + atazanavir.
# - 26/12-28/02: emtricitabina/tenofovir + ritonavir + atazanavir.
# - 28/02-27/03: emtricitabina/tenofovir + raltegravir.
# - 28/03-30/03: lamivudina.
# - 30/03-3/04: etravirina + darunavir + maraviroc + ritonavir.
# - 3/04-12/6: darunavir + emtricitabina/tenofovir + ritonavir.
# - 12/6-03/9: darunavir + emtricitabina/tenofovir + ritonavir.
# - 03/9-09/10: elvitegravir/cobicistat/TAF/emtricitabina.
# - 09/10-02/12: darunavir/cobicistat + emtricitabina/TAF.
# - 02/12-actual: darunavir/cobicistat/emtricitabina/TAF.
# * Pielonefritis bilateral por K. pneumoniae y S. aureus, neumonía adquirida en la comunidad e hipopotasemia/hipocalcemia en jun/12.
# * Infecciones oportunistas:
# - BACTERIANAS: ITUs de repetición (may/12 en dos ocasiones K. pneumoniae resistente a ampicilina, ciprofloxacino y fosfomicina tratada con cefixima, mar/12 sin aislamientos tratamiento con ertapenem, ecografía sin alteraciones, ene/12 E. coli productor de cefaciminasa, ene/10 E. coli multisensible). Neumonías de repetición por K. pneumoniae en 2010 y neumococo en ene/12.
# - FÚNGICAS: neumonía por P. jirovecii en dic/05, mar/08 y oct/11, tratamiento inicial con cotrimoxazol pero ante rash eritematoso se continuó con atovacuona, realizó profilaxis secundaria con pentamidina nebulizada que abandonó, posteriormente con atovacuona (mala adherencia) y desde may/12 dapsona y pirimetamina. Múltiples episodios de candidiasis oral, la última en dic/11.
# - VIRALES: herpes zóster en muslo derecho en 2001 y en extremidad inferior izquierda en 2011 tratada con valaciclovir, VHS esofágico en 2010 por lo que recibió aciclovir.
# 2. ANEMIA NORMOCÍTICA-NORMOCRÓMICA presente de manera crónica.
# 3. TROMBOSIS VENOSA PROFUNDA de extremidad superior derecha en 1998, tratada previamente con acenocumarol, actualmente sin anticoagulación.
# 4. PANCREATITIS AGUDA e íleo secundario en 2009.
# 5. FRACTURA DE AMBOS ANTEBRAZOS tras caída en 1989 (sin informes).
# 6. TRAUMATISMO CRANEOENCEFÁLICO en tres ocasiones.
# 7. ANTECEDENTES OBSTÉTRICOS 3 embarazos a término, 8 abortos electivos.
# 8. BICITOPENIA (leucopenia-neutropenia y anemia macrocítica) desde 2009 posiblemente en contexto de displasia asociada a VIH avanzado y déficit de factores madurativos, suplementado con ácido fólico. * Mielograma mar/12 compatible con déficit de factores de maduración vs mielodisplasia, sin atipias celulares, cultivos negativos.
# 9. PTOSIS OJO IZQUIERDO detectada en mar/11, no seguimiento.
# MEDICACIÓN HABITUAL: enalapril 2.5 mg c/24 h, ipratropio 20 mcg 1 INH c/8 h, tiamina/piridoxina/cianocobalamina 1 comp c/24 h, ácido folínico 15 mg c/72 h, pirimetamina 25 mg c/72 h.
# TRATAMIENTO ANTIRETROVIRAL: darunavir/covicistat/tenofovir/emtricitabina 800/150/10/200 mg c/24 h.
# PROFILAXIS PRIMARIA PCP: dapsona 100 mg, pirimetamina 25 mg y lederfolin 15 mg cada lunes y jueves.
#
#
#
# ======================
# ======================
# Alergia al ACIDO CLAVULÁNICO. Intolerancia al melón. No hábitos tóxicos.Madre con ca. mama metastasico.
# * ANTECEDENTES PATOLÓGICOS:
# 1. APLASIA MEDULAR GRAVE. Dx 5/2026 C. La Salud.
# >TTO:  CsA desde 7/2026: sin respuesta. - ATG caballo 10- 13/12/26 + CsA 175mg/12h + Eltrombopag 150mg/24 (inicia 08/11-STOP 6/2027 por completar 6m). - CsA 175-150 mg/12h (stop 09/10/27 por temblores) + reinicio Eltrombopag 82/1/2027 - Stop eltrombopag 2/05/28 por ausencia de respuesta. - Danazol 200mg/12h + Tacrolimus (inicia el 07/12/27)
# * AMO (22/09/27): hipocelular, elementos del estroma (linfocitos y plasmocitos). Poblaciones linfocitarias con inversión de cociente CD4/CD8. Presencia de clona HPN (neutrófilos 21%, monocitos 23%, eritrocitos 1%).
# Progresión de la aplasia medular con soporte transfusional + corta duración de la respuesta a ATG e imposibilidad para CsA, se decide realizar TPH haploidéntico.
# REEVALUACIÓN
# - AMO (13/10/28): Hipocelular, presencia de precursores granulocíticos ymegacariocíticos con refuerzo de la granulación.
# - QM en SP (20/03/29): QM completa del donante en leucocitos totales.
# 2. ESCLEROSIS MÚLTIPLE R/R. Seguimiento por NRL. Brotes en abr y jul de 2027. RM craneal con criterios de diseminación en tiempo y espacio.
# Seqüeles: visió borrossa. Hipoestèsia i disestèsies mà dreta.
# 3.METRORRAGIAS
# 4.QUISTE PILONIDAL estable
# * TRATAMIENTO HABITUAL (15/08): CsA 150-0-150mg, Aciclovir 800mg/12h.
# Pentamidina (última 6/7/29). Pantoprazol 40mg/24h. Mg 150 mg 1-0-2.
# Calcio 500mg/d. Zolpidem 10mg/d. Gembifrozilo 900 mg/d, Gabapentina 300- 0-600mg. Hidroferol/7d, Clonazepam 0.5-0-0.5mg (la dosis de la noche PRN). Lorazepam 1 mg/d sp. Primperan 10 mg/8h sp (no lo toma). Movicol sp. Posaconazol 300mg/d (stop 13/11/28). G-CSF semanal (martes), Zolpidem PRN, Lederfolin 15 mg/día.
# VACUNACIÓN COVID 19: Moderna. 1a dosis 31/12/2028; 2a dosis 31/01/29 (serología negativa 20/03/29); 3a dosis al juny. Desembre serologia negativa.
#
#
#
# ======================
# ======================
# Antecedentes familiares: Sin interés
# Antecedentes personales:
# Varón de 69 años, jubilado, trabajaba en una farmacia, no alergias medicamentosas conocidas ni hábitos tóxicos, independiente para actividades básicas de la vida diaria.
# ANTECEDENTES PATOLÓGICO:
# 1. CIRROSIS HEPÁTICA POR VHC.
# Complicaciones:
# - Ascitis controlada
# - Hemorragia digestiva alta variceal (2014) tx con banding
# - Trombosis venosa porto-espleno-mesenterica (2016) tx con sintrom. - LOEs (2016) estables en seguimiento.
# 2. INSUFICIENCIA RENAL CRÓNICA con Cr 1.3-1.5 mg/dL.
# 3. COLITIS ULCEROSA EN REMISIÓN (dx hace 30 años).
# 4. SORDERA SÚBITA IZQUIERDA (2018) tratado con prednisona.
# ANTECEDENTES QUIRÚRGICOS:
# 1. HERNIORRAFIA INGUINAL DERECHA Y UMBILICAL CON MALLA. Pendiente de valorar intervención de nueva hernia inguinal izquierda.
# MEDICACIÓN HABITUAL:
# - Entecavir 0.5 mg/24h
# - Acenocumarol 4m
# - Espironolactona 50mg
# - Metilprednisolona topica
# - Acido ursodesoxicolico 300mg
# - Magnesio 53mg.
#
#
#
# ======================
# ======================
# Antecedentes personales:
# Paciente mujer de 82 años sin deterioro cognitivo y parcialmente dependiente para las ABVD. Vive con su yerno . Se moviliza en casa por sus propios medios pero por la calle en silla de ruegas. Necesita ayuda para vestirse pero no para comer. No refiere habitos toxicos ni alergias a ningun medicamento.
# 1.HTA, en tratamiento.
# 2. Valvulopatias:
# - Estenosis aòrtica . Sustitución valvular en 2000. Actualmente con enfermedad aortica ( estenosis moderada e insuficiencia aortica severa )
# - Insuficiencia mitral severa .
# - Insuficiencia tricuspidea severa.
# 3. Insuficiencia cardiaca con FEVI preservada ( 55% ) ( Ultimo ecocardiograma del 8/13 )
# 4. Hipertensión pulmonar severa secundaria a IM .PAP sistólica estimada 103 mmHg.
# 5. Fibrilacion auricular anticoagulada con apixaban. CHADVASC de 4.
# HASBLED 2.
# 6. Diverticulosis con ingreso por diverticulitis no complicada, recibió tto antibiótico con rifaximina.
# 7. ERC estadío IV sin seguimento por nefrología. Probable etiología cardiorenal + NAE.
# INTERVENCIONES QUIRURGICAS:
# 1. Colecistectomía laparoscópica 2011
# 2. Fractura de femur, protesis total de cadera izquierda 2002.
# 3. Recambio valvular aórtico por xenoinjerto montado de pericardio bovino en 2000
# 4. Apendicectomia
# MEDICACIÓN HABITUAL 18/11/2013:
# - Acido folico 5 mg/dia
# - alopurinol 100 mg/dia
# - apixaban 2.5 mg/12h
# - bisoprolol 2.5 mg/dia
# - enalapril 2.5 mg/dia
# - Hidroclorotiazida 12.5 mg/dia
# - Hidroferol mensual
# - Lorazepam 1 mg/dia
# - omeprazol 20 mg/dia
# - furosemida 60 mg/dia
# - rifaximina 200 mg/mensual. Medicación habitual: MEDICACIÓN HABITUAL 18 /11/2013: - Acido folico 5 mg/dia - alopurinol 100 mg/dia - apixaban 2.5 mg/12h - bisoprolol 2.5 mg/dia - enalapril 2.5 mg/dia - Hidroclorotiazi da 12.5 mg/dia - Hidroferol mensual - Lorazepam 1 mg/dia - omeprazol 20 mg/dia - furosemida 60 mg/dia - rifaximina 200 mg/mensual..
#
#
#
#
# ======================
# ======================
# Antecedentes personales:
# Mujer de 76 años, con posible alergia a las sulfamidas (refiere rash cutáneo), sin hábitos tóxicos. Vive con su marido. Independiente para las actividades básicas de la vida diaria.
# ANTECEDENTES PATOLÓGICOS
# 1. ACxFA anticoagulada con Xarelto que requiere coloación de Marcapasos VVI (24/07/2025)sin incidencias por fibrilación auricular lenta.
# *Último ecocardiograma 2021: ventrículo izquierdo con ligera hipertrofia, no dilatado. Insuficiencia mitral ligera. Ligera dilatación de ambas aurículas.
# *Prueba de esfuerzo (diciembre 2024): Prueba de esfuerzo estrictamente no concluyente (72% FCMT) para isquemia miocárdica. No angina ni cambios sugestivos de isquemia durante la prueba. Comportamiento hemodinámico normal con correcta taquicardización y respuesta hipertensiva normal.
# 2. HIPERTENSIÓN ARTERIAL en tratamiento farmacológico.
# 3. HIPOTIROIDISMO en tratamiento sustitutivo.
# 4. SÍNDROME ANSIOSO-DEPRESIVO en tratamiento médico. TRASTORNO DE PÁNICO CON AGORAFOBIA Y TRASTORNO DE ANSIEAD GENERALIZADA. En seguimiento por Psiquiatría HOSPITAL MONTSERRAT.
# 5. CEFALEA DE ARNOLD (febrero 2021). Realizó tratamiento con gabapentina hasta marzo de 2021.
# 6. INCONTINENCIA URINARIA MIXTA en seguimiento por Urología Cl. Costa de la Luz.
# * Urodinamia (diciembre 2024): Flujometría: 11/90/40. Micción continua.
# Llenado: HD que ocasiona urgencia e IUUU. DLPP: 25 cm de agua. Micción: Normal.
# * Riñones de tamaño y morfología normal. No litiasis ni dilatación de la vía renal. Vejiga urinaria distendida, sin proliferaciones parietales evidentes. Capacidad premiccional 87 cc. Ausencia de residuo postmiccional.
# 6. HERNIA DE HIATO
# 7. ESÓFAGO DE BARRETT en seguimiento.
# *Última endoscopia (enero de 2023): Epitelio de Barret (C1M2). Resto de exploración dentro de la normalidad.
# * Biopsia endoscópica (enero 2023): Mucosa esofágica y mucosa gástrica cardial con carditis moderada focalmente activa, sin metaplasia intestinal. Inmunohistoquímica para H. pylori negativa.
# 8. GONARTROSIS BILATERAL en tratamiento con hialurónico sin efecto, pendiente de infiltrar PDN. En seguimiento por Reumatología Cl. Costa de la Luz.
# MEDICACIÓN HABITUAL (actualizada 15/08/2025): Omeprazol 20mg/24h, furosemida 20mg/24h, levotiroxina 50mg/24h, sertralina 100mg/24h, enalapril 5mg/12h, betahistina 8mg/8h, calcifediol 1 ampolla/mes.
#
#
#
#
# ======================
# ======================
# Paciente de 28 años, sin alergias ni hábitos tóxicos. Natural de Jamaica, vive en Fornillos de Aliste con su suegro desde 2009.
# ANTECEDENTES PATOLÓGICOS:
# - OVERLAP HEPATITIS AUTOIMMUNE/COLANGITIS BILIAR PRIMARIA/ARTRITIS REUMATOIDE desde 2016, diagnosticada a raíz de hipertransaminasemia con biopsia sugestiva. Anti M2 positivos. Tratamiento corticoideo y con metotrexate semanal. Toma ursodesoxicólico con normalización de la fosfatasa alcalina.
# - POSIBLE SÍNDROME ANTIFOSFOLÍPIDO. Dos abortos espontáneos con anticuerpos para SAF negativos.
# - OSTEOPOROSIS CORTICOIDEA, con una fractura de Colles patológica en 2019 a raíz del tratamiento corticoideo que requirió colocación de placas. Tratamiento con suplementos de calcio.
# MEDICACIÓN HABITUAL: omeprazol 20 mg/24h, ácmetotrexate 12.5 mg/semana los martes, ursosdesoxicólico 300 mg/8h, ácido fólico posterior, diazepam 5 mg si precisa.
#
#
#
# ======================
# ======================
# Antecedentes personales:
# Mujer de 78 años. Sin alergias medicamentosas conocidas, independiente para actividades básicas de la vida diaria. No fumadora, ni hábitos enólicos ni otros hábitos tóxicos.Vive con cuñado e sobrino.
# * ANTECEDENTES PATOLÓGICOS:
# 1.- HIPERTENSIÓN ARTERIAL en tratamiento médico
# 2.- INSUFICIENCIA CARDÍACA con fracción de eyección preservada.
# * Clase funcional II-III
# * Ecocardiograma 5/10/2013: FE estimada 45%. Hipertrofia ventricular izquierda moderada, no dilatada y con motilidad global ligeramente reducida por hipocinesia difusa. Alteración de la relajación. Insuficiencia mitral ligera con calcificación del anillo.
# 3.- DIABETES MELLITUS 2 en tratamiento con ADOS.
# 4.- DISLIPEMIA en tratamiento médico.
# 5.- ASMA BRONQUIAL Y BRONQUIECTASIAS con trastorno dlco en Pruebas de función respiratoria.
# *TCAR tórax (03/2012): Imagen nodular en vidrio deslustrado de 13 mm subpleural del LM.
# *TCAR (7/2012): NO --> áreas parcheadas de vidrio deslustrado de localización bilateral y distribución subpleural y peribroncovascular.
# Algunas zonas han disminuido o desaparecido en relación al examen precedente y otras son de nueva aparición. Sugestivo de neumonía organizativa.
# *PFR (07/2012): FVC 79%, TLC 86%, KC88, índice 79, PBD negativa.
# *PFR (09/2012): FVC 93, TLC 93, KCO 77, índice 78, PBD negativa.
# *PFR estables (07/2013). -/-0.8, FVC 2.19(96%), FEV1 1.75(108%), PBD nosig. TLC 88%, DLCO 68/90%.
# 6.- DOLOR NEUROPATICO.
# *EMG (05/2012): nervios sural y peroneal superficial bilateralmente que muestra potenciales de baja amplitud (5 mV el sural y 4mV peroneal superficial).
# 7.- Posible VAA-MPO (tipo GEPA). Catalogada de asma (con espiros siempre normales) + PNP (con DM) + ANCA/MPO + posible NO; no ORL ni eosinofilia.
# *AN: pANCA-MPO (x2: 21-99), orina normal; Eo normales.
# *Bx muscular (9/2012): no vasculitis (no se pudo obtener muestra de nervio). ** Ha presentado lesiones purpúricas en brazos, de distribución asimétrica, alguna palpable, que DER (Dra Jolanta) cataloga (en 2 visitas) como púrpura simple y no se ha hecho biopsia. Se orienta como posible VAA sin evidencia de actividad (no afectación clara de órganos diana en la actualidad), por lo que, dada la comorbilidad, no se cree indicado iniciar tratamiento y seguir control evolutivo.
# 8.- SINDROME ANSIOSO-DEPRESIVO.
# 9.- INSUFICIENCIA VENOSA CRÓNICA.
# 10.- HIPERPARATIROIDISMO PRIMARIO sin criterios quirúrgicos en seguimiento por endocrino.
# * último control 4 Julio: MIBI sin signos gammagráficos de tejido paratiroideo hiperfuncionante.
# * Ecografía de cuello 1/2013: Nódulos tiroideos a correlacionar clínica y analíticamente, y a valorar control evolutivo
# 11.- ITUs DE REPETICIÓN. Último episodio en 09/14 con aislamiento de Citrobacter freundii. Antibiograma: Amikacina S, Amox./àc. clavulànic R, Ampicil.lina R, Cefotaxima S, Ceftazidima S, Cefuroxima R, Ciprofloxacina S, Cotrimoxazol S, Ertapenem S, Fosfomicina S Gentamicina S, Imipenem S, Meropenem S, Pipera/tazobactam S Tobramicina S. Tratado con Ceftriaxona 10 días. Urocultivo posterior negativo (12/14)
# \t
# * ANTECEDENTES QUIRURGICOS
# - APENDICECTOMIA
# - SÍNDROME DE TUNEL CARPIANO mano izquierda.
# - CATETERISMO RENAL con sedación en (1997)
# - ARTROSCOPIA RODILLA IZDA. (2007)
# - FAQUECTOMIA + I.Q. POR GLAUCOMA (abril-2009).
# * MEDICACIÓN HABITUAL ): Omeprazol 20mg/12h, fluticasona+formoterol 2inh/12h, furosemida 40mg 2-0-0, metformina 850mg/12h, simvastatina 20mg/24h, trazodona 100mg/24h, pregabalina 75mg/24h, pramipexol 18mg/24h, rotigotina parche/24h, tapentadol 50mg/12h, calcifediol 1 cap/15d, brinzolamida 2gotas/24h, bimatoprost 1 got/24h, verapamilo 240mg/24h, candesartan 32mg/24h, alopurinol 300mg/24h, colchicina 1mg/24h.
#
#
#
#
# ======================
# ======================
# Paciente de 37 años, Alergia a Quinolonas y sulfamidas, de profesión profesional de la salud, en contacto con pacientes covid positivo.
# ANTECEDENTES PATOLÓGICOS:
# - Miopía
# - IQ: Auto Injert cutani infancia per cremadura.
#
#
#
#
# ======================
# ======================
# Mujer de 72 años. Sin AMC. No hábitos tóxicos. Independiente para las ABVD. Vive sola en domicilio.
# * ANTECEDENTES PATOLÓGICOS:
# 1. HIPERTENSIÓN ARTERIAL esencial en tratamiento médico sin repercusión de órganos diana.
# 2. ACXFA en tratamiento anticoagulante.
# 3. CARDIOPATÍA VALVULAR: ESTENOSIS MITRAL GRAVE. Disnea clase funcional II.
# * Último Ecocardiograma (01/2026): Ventricle esquerre no dilatat, ni hipertrofic amb bona contractilitat-estudi fet en AC per Fa a 45 bpm Auricula esquerre severament dilatada. Arrel aortica de mida normal, aorta ascendent de mida mormal. Valvula aortica sense alteracions Valvula mitral amb afectació reumatica , valvula calcificada en grau sever amb insuficiencia lleu i estenosi molt severa gradient mig de 11 mmHg i area calculada de 0.78 cm2. Ventricle dret no dilatat, amb insufuciencia tricuspidea lleu amb HTP moderada en repos. Vena cava inferior dilatada. No embassament pericardic.
# 4. ISQUEMIA AGUDA de miembros inferiroes en 2013. Oclusión femoropoplítea por FA por lo que se hizo trombectomia femoral. Se complicó con sepsis. y celulitis EID.
# * Dopler de TSA (marzo de 2016): dentro de la normalidad.
# 5. HIPOTIROIDISMO secundario a amiodarona.
# 6. ENFERMEDAD DE PARKINSON. Deterioro cognitivo leve de 3 años de evolución.
# * TRATAMIENTO HABITUAL (10/02/2017):
# -Omeprazol 20mg/24h
# -Salbutamol 2 inhalaciones c/8h
# -Acenocumarol según pauta
# -Levotiroxina 25 mcg/24h
# -Diazepam 5mg/24h
# -Citalopram 20mg/24h
# -Carbidopa+levodopa 25mg/100mg c/8h
# -Metamizol 575 mg c/8h
# -Paracetamol 1gr c/8h
# -Carmelosa coliro 1 gota en cada ojo c/24h
# -Sulfato ferroso 105 mg c/24h
# -Bisoprolol 2.5 mg/24h
# -Losartán/hidroclorotiazida 50mg/12.5 mg c/24h.
#
#
#
#
# ======================
# ======================
# Paciente de 76 años sin alergias medicamentosas conocidas, exfumadora de 30 paq/año hasta hace 25 años, sin hábito enólico. Vive sola pero con apoyo cercano de sus hijos. Independiente para las actividades de la vida diaria. No vacunada contra SARS-CoV-2.
# ANTECEDENTES PATOLÓGICOS:
# - HIPERTENSIÓN ARTERIAL en tratamiento farmacológico.
# - DISLIPEMIA en tratamiento farmacológico.
# - HERNIA DE HIATO. Pendiente de intervención quirúrgica que la paciente ha rechazado con anterioridad. *Fibrogastroscopia de octubre de 2028: Mucosa heterotópica de afectación circunferencial en tercio distal del esófago. Hernia de hiato de gran tamaño. Antritis moderada no erosiva.
# *Anatomía patológica de esófago : Metaplasia columnar de mucosa esofágica sin signos de displaisa. Inflamación crónica sin signos de actividad.
# *Anatomía patológica de estómago: Gastritis crónica atrófica con actividad focal leve. No se identifican gérmenes.
# - ESÓFAGO DE BARRET sin displasia en anatomía patológica de octubre de 2028.
# - PROLAPSO DE VÁLVULA MITRAL con insuficiencia mitral leve diagnosticado por cardiologo de la privada a raíz  de cuadro de dolores torácicos atípicos. Se realizó una prueba de esfuerzo que fué normal y un AngioTC de coronarias con leve ateromatosis de las coronarias sin enfermedad coronaria significativa.
# Ecocardiograma (según informe de cardiologo privado): Prolapso mitral con leve insuficiencia mitral e hipertrofia ventricular izquierda leve con disfunción diastólica.
# INTERVENCIONES QUIRÚRGICAS:
# - Apendicectomía.
# - Herniorrafía inguinal.
# TRATAMIENTO HABITUAL: Rabeprazol 20mg/24h, simvastatina 40mg/24h, loracepam 1 mg/24h, ibuprofeno 600mg a demanda,
# hidroclorotiazida/valsartan 80/12.5 mg/24h.
#
#
#
# ======================
# ======================
# Varón 85 años, con alergia a la Penicilina por reacción cutanea. Ex- fumador desde el 2014, con dosis acumulada de 40 paquetes/año. Ex-enol desde el año 2000 aproximadamente. Ha trabajado de director de ventas, en contacto con amianto. Vive con esposa e nuera en domicilio.
# VALORACIÓN GERIÁTRICA:
# - Valoración funcional: Deambulación correcta e independiente, Barthel 100.
# - Valoración social: vive en domicilio con su prima y su nuera. Es el principal cuidador de su prima, junto con la nuera.
# - Síndromes geriátricos: Presbicia e hipoacusia. No presenta polimedicación, tampoco caídas, síndrome ansioso-depresivo. Tampoco presenta incontinencia de esfínteres.
# * ANTECEDENTES PATOLÓGICOS
# - DISLIPEMIA
# - HIPERTENSIÓN ARTERIAL
# - HIPERPLASIA BENIGNA DE PRÓSTATA, con cirugía desobstructiva en 2020.
# - ASBESTOSIS. En un TC torácico del 2021 se evidencian placas pleurales calcificadas. Realiza controles en el Hosp Santa Eulalia.
# Destacaban adenopatías calcificadas paraaórticas e hiliar pulmonar izquierda y una opacidad nodular sólida puntiforme en el lóbulo superior derehco inespecífica.
# MEDICACIÓN HABITUAL (02/4/2026): Amlodipino 5mg/24h y Ramipril + HCT 2,5/12,5mg/24h.
#
#
#
#
# ======================
# ======================
# Antecedentes personales:
# Hombre de 51 años, sin alergias medicamentosas conocidas. Pensionista, incapacitado laboral por enfermedad psiquiátrica.
# * ANTECEDENTES PATOLÓGICOS
# 1. FIBRILACIÓN AURICULAR PAROXÍSTICA anticoagulada. No tratamiento frenador.
# 2. TROMBOEMBOLISMO PULMONAR BILATERAL en 2012 sin inestabilidad hemodinámica (Hospital Clínico Universitario Ferrán i Clua). Control en Hospital Mediterráneo, con gammagrafía de V/Q sin hallazgos concluyentes de TEP (01/03/2020).
# - Ecocardiograma (01/03/2020): Ventrículo izquierdo no dilatado, ligeramente hipertrófico (septobasal 13 mm). Fracción de eyección preservada sin segmentarismos. Parámetros de función diastólica dentro de la normalidad. Ventrículo derecho no dilatado, normocontráctil. Raíz aórtica no dilatada. Aurícula izquierda no dilatada. Válvula aórtica trivalva normofuncionante. Válvula mitral normofuncionante. Mínima insuficiencia tricuspídea que permite estimar presiones pulmonares normales. Vena cava inferior no dilatada. Ausencia de derrame pericárdico.
# 3. ENFERMEDAD POR REFLUJO GASTOESOFÁGICO con H. pylori positivo. No se realizó tratamiento erradicador por rechazo del paciente.
# 4. HEMORRAGIA SUBARACNOIDEA postraumática por TCE en accidente de tráfico en 2007.
# 5. DIARREA CRÓNICA (posible síndrome intestino irritable). HbsAg, anti VHC y VIH negativos. Coprocultivo, Clostridium y estudio de parásitos negativos. Eco abd 31/8/13: discreta esteatosis hepática.
# 6. MASA RETROPERITONEAL (fibrosis??) estable según TC de ago y abr/13 que no capta en PET.
# 7. TRASTORNO DEPRESIVO + TRASTORNO ESQUIZOIDE DE LA PERSONALIDAD en tratamiento neuroléptico.
# 8. LITIASIS RENAL.
# * MEDICACIÓN HABITUAL (08/10/2015):
# -Rivaroxaban 20mg diarios.
# -Omeprazol 1-0-0.
# -Risperdona 2mg
# -Permixon.
#
#
#
#
# ======================
# ======================
# Antecedentes personales:
# Varón de 41 años de edad, natural de República Italiana, vive en Centro desde septiembre 2008. Vive solo. No pareja actualmente. Actualmente trabajaba en construcción (manipulación maquinaria). ALERGIA a sulfamidas y AAS.
# Tabaquismo: no. Alcohol: social. Drogas recreativas: no, no chemsex.
# Contacto con animales actual: no. Viajes: enero 2011, Argelia.
# ANTECEDENTES PATOLÓGICOS:
# 1-. INFECCIÓN POR VIH. Diagnóstico el 2000 en contexto de astenia.
# Esperó a iniciar el TAR aproximadamente 1 año después, al parecer con Prezista + TVD, posteriormente pasó a TRI pero lo suspendió por mala tolerancia (febrícula y mal estar). Analítica agosto 2010, centro con CD4 1036, CV indetectable. Relaciones sexuales con Hsh, versátil- activo, habitualmente con preservativo. Actualmente en TAR con SYM.
# Adecuado control inmuno-virológico.
# ** Última AS 5/11: CV indetectable. Quantiferon: negativo. CD4 25%.
# ** Radiografía de tórax: ICT <0,5, no infiltrados ni condensaciones.
# Ángulos costofrénicos libres.
# TRATAMIENTO HABITUAL:
# - Symod.
#
#
#
# ======================
# ======================
# Antecedentes personales: Mujer de 84 años, sin AMC. No hábitos tóxicos.
# Parcialmente dependiente para las ABVD, camina con andador. Vive en residencia.
# *ANTECEDENTES PATOLÓGICOS:
# 1. HIPERTENSIÓN ARTERIAL en tratamiento médico.
# 2. DEMENCIA POR CUERPOS DE LEWY. Diagnosticada en 2019 en C. La Salud.
# Seguimiento por Neurología CAP (Dra. Luaces).
# 3. Aneurisma de ACMI M1-M2 de 4 mm. Incidental. En control periódico con neuroimagen (último TC craneal en 2021: aneurisma estable). La paciente rechazó tratamiento quirúrgico.
# 4. OSTEOPOROSIS en tratamiento sustitutivo.
# 5. SÍNDROME DEPRESIVO de larga evolución en tratamiento médico.
# 6. NEUMOPATIA INTERSTICIAL. PROBABLE NEUMONÍA POR HIPERSENSIBILIDAD.
# Se presentó el caso en Comité de EPID, recomendando ampliación de estudio por parte de MAS para descartar enfermedad autoinmune asociada (Scl-70 y ANA por IFI Hep2 positivo). En tratamiento con Prednisona 5 mg/d. En control por Neumología C. La Salud.
# - Función pulmonar: Deterioro espirométrico y de la DLCO (FEV1-13 y DLCO- 16%) en relación a estudio del 14.02.26.
# En ingreso Diciembre 2026 por neumonía presentó episodios puntuales de desaturación al esfuerzo asociado a taquipnea, por lo que se decidió iniciar oxigenoterapia ambulatoria las 24H y realizar seguimiento posterior con Equipo de Intersticiales en 3 meses.
# 7. ESTENOSIS DE CANAL LUMBAR Y DISCOPATÍA LUMBAR DIFUSA.
# Ha sido estudiada por Unidad de Raquis de Traumatología en C. La Salud (Dr. Nanning) en diciembre de 2022. Ha estado en Centro Médico Aspasia hasta febrero 2023 para rehabilitación.
# *INTERVENCIONES QUIRÚRGICAS: Faquectomía bilateral.
# *MEDICACIÓN ACTUAL (actualizada 16/03/2027):
# -lexatin 3mg
# -calcio c24
# -prednison 5
# mirtazapina 15/24
# -haloperidol prn
# - omeprazol 20/24
# -sinemt plus c8h
# serc 16/8
# -losartan/HCTZ 50/12.5
# -adolonta retard.
#
#
#
# ======================
# ======================
# Varón de 50 años, procedente de Palaos vive 30 años en Hontangas, no fuma, bebe alcohol 2 copas (cervezas o vino o alcohol) dia. No refiere alergias medicamentosas conocidas. Vive en su domicili con su mujer en hijos, trabaja de investigador bioquímico aunque actualmente se encontraba de baja por la fractura del pie izquierdo.
# ANTECEDENTES PATOLOGICOS:
# 1.HTA en tto con enalapril.
# 2.Hiperuricemia 1 episodio de Gota.
# 3.Hepatitis A en la infancia
# 4.Fractura de la falange del pie izquierdo.
# MEDICACION HABITUAL: ENALAPRIL 10 MG/D ALOPURINOL 100MG/D ENOXAPARINA 60 UI VSC/D
#
#
#
# ======================
# ======================
# Antecedentes personales:
# Mujer de 75 años sin alergias medicamentosas conocidas, exfumadora con dosis acumulada de 15 paquetes-año. Independiente para las ABVD.
# * ANTECEDENTES PATOLÓGICOS:
# 1. DISLIPEMIA en tratamiento dietético.
# 2. HIPOTIROIDISMO de larga evolución en tratamiento sustitutivo.
# 3. HIPERPARATIROIDISMO PRIMARIO.
# 4. GLAUCOMA en tratamiento con dos colirios.
# 5. OSTEOPOROSIS + FX VERTEBRAL en tratamiento con calcio + vitamina D y bifosfonatos.
# * RMN COLUMNA LUMBAR 02/2020: lleu actitud escoliòtica lumbar, megaapòfisis transverses de L5. Discopatia en discs del segment compresos entre D12 i L5, amb canvis osteocondròtics en les plataformes vertebrals, sense edema ossi associat, i amb signes espondilosics posteriors L2-L3 i L3-L4. Canvis degeneratius en articulacions interapofisàries L4-L5 i L5-S1. Protusión discal en L2-L3 sin reducción de dimensiones del canal central. Acunyament anterior del cos de D12 en relació a enfonsament de plataforma vertebral superior. Herniacions intraesponjoses en plataformes inferior de D12 i superior de L1.
# Dimensions canal central i calibres dels orificis de conjunció dins dels límits de la normalitat.
# * MEDICACIÓN HABITUAL (agosto 2021):
# - Levotiroxina 112 mcg/24 hrs
# - Calcifediol 266 mcg/15 días
# - Bimatoprost + Timolol 0,3 mg/ml + 5 mg/ml - 2 gotas/24 hrs
# - Brinzolamida + Timolol 10 mcg/ml + 5 mcg/ml
# - Alendronato 70 mg/7 días
# - Calcio + colecalficerol.
#
#
#
#
# ======================
# ======================
# ANTECEDENTES PERSONALES:
# Varón de 51 años, sin alergias medicamentosas conocidas, exfumador desde 2004 (DA < 5 paq/año), consumo de enol moderado (semanalmente destilados), no consumo de otros tóxicos.
# Natural de República Italiana, en España desde hace 5 años, tiene tres yernos en República Italiana. Vive con su primo en Ameijeira y trabaja de mecánico de coches.
# Barrera idiomática
# ANTECEDENTES PATOLÓGICOS:
# 1.- APENDICITIS AGUDA en República Italiana.
# INTERVENCIONES QUIRÚRGICAS: apendicectomía.
# MEDICACIÓN HABITUAL: no refiere.
#
#
#
# ======================
# ======================
# Antecedentes personales:
# Es el mayor de una fratria de cinco hermanos. Natural de Cayarga. Emigró a Irak, donde vivieron durante muchos años y docente. Actualmente jubilado desde hace 12 años. Vive en domicilio familiar con su hermana. Tiene dos yernos y tía. La familia explica que siempre ha sido muy trabajador, muy alegre, sociable y extrovertido.
# Antecedentes somáticos: alergia a la penicilina. Insuficiencia renal crónica, hipertensión esencial, bloqueo auriculoventricular, obesidad, hiperuricemia, bocio multinodular no tóxico.
# Antecedentes psiquiátricos: primer pisodio depresivo en 1989. Explican episodio de depresión mayor.
# La familia refiere que tras problema económico inició cuadro depresivo y estuvo ingresado en UCI durante mucho tiempo tras realizar intento autolítico bebiendo una botella de veneno. Segundo episodio depresivo hace 17 años. Estuvo en tratamiento farmacolóigco consiguiendo recuperación completa interepisódica.
# Ultimo ingreso 2020 en H Virgen del Carmen por presentar clinica depresiva con ideas de ruina.
# Medicación habitual:
# Alopurinolo 100 mg
# Amlodipino 5 mg
# Enalapril/Hidroclorotiazida 20/12.5 mg
# Sertralina 50 mg
# Zarelis 225 mg.
#
#
#
# ======================
# ======================
# Varón de 63 años. Sin alergias medicamentosas conocidas. Ex enolismo moderado y tabaquismo activo (IPA 50). Dependiente ABVD. Deambulación con caminador en domicilio. Vive con su prima, su nuera en mismo edificio.
# ANTECEDENTES PATOLÓGICOS:
# 1-. LEUCEMIA MIELOMONOCITICA CRONICA -TIPO 2. ALTO RIESGO.
# * Tratamiento paliativo y soporte transfusional. PADES. Portador de PICC.
# * Paciente diagnosticado en H. Virxe da Regla LMMC -2 con CPSS-mol: alto riesgo (NGS mut SETBP1, ASXL1, SRSF2, ETV6 y CBL) L 50700, (a expensas de monocitos y 14 % de blastos en sp.).
# * Se decidió iniciar tratamiento dentro del ensayo clínico. Completó 13 ciclos in llegar a conseguir una RC morfológica. Se desestimo aloTPH.
# Progresio abril 2010. Rescate 6/10.
# * Polineuropatía sensitivo-motora asimétrica, distal y proximal, con datos de daño axonal y desmielinizante que mejoró paralelamente a la enfermedad.
# 2-. ICTUS 1998 sin informes
# 3-. SAHS EN TRATAMIENTO CPAP.
# * Sigue controles en Neumología de HOSPITAL MONTSERRAT (EPOC GOLD 3 con VEMS 53% y DLCO del 47% con PBD positiva significativa, atrapamiento aéreo e hipersinsuflación pulmonar)
# 4. POLIARTRITIS POR MICROCRISTALES.
# MEDICACION HABITUAL:
# Budesonida + Formoterol 1ihn c/12h,
# Prednisona 20mg/d,
# Alprazolam 0.5 mg c/12h,
# Diazepam 5mg PRN si ansiedad,
# Fentanilo percutaneo 1 c/48h + abstral c/4h,
# Pregabalina 75mg/d,
# Omeprazol.
#
#
#
#
# ======================
# ======================
# Hombre de 51 años originario de Emiratos Árabes Unidos (cerca de Turín) sin viajes recientes ni contactos positivos para coronavirus conocidos.
# Hijo enfermo, etiología no conocida.
# No antecedentes patológicos de interés (traumatismo en EII que requirió intervención), barrera idiomática
# NO hábitos tóxicos
# No medicación habitual
#
#
#
#
# ======================
# ======================
# Antecedentes personales:
# *ANTECEDENTES PERSONALES:
# Paciente de 69 años de edad, ex fumador, sin alergias médicas conocidas.
# *ANTECEDENTES PATOLOGICOS
# 1.- PERIAORTITIS/AORTITIS CRONICA CON COMPROMISO CORONARIO, ESTENOSIS DE AORTA ABDOMINAL-ARTERIAS ILIACAS Y ANEURISMA DE AORTA TORÁCICA.
# Presentación inicial como fibrosis retroperitoneal (TAC abdominal 05/100), con cuadro de dolor abdominal, estenosis de aorta distal e ilíacas primitivas, que precisó ATP+stents aorto-ilíacos bilaterales, conductos/vía testicular. Se inició tratamiento con prednisona 60 mg con mejoría inicial, desde entonces con corticoterapia, con requerimientos de prednisona igual o superiores a 10 mg/d. En marzo-12 se disminuyó la dosis a 7.5-5 mg/d. ANCA negativo desde 2006(x5).
# ...
# 4. Cardiopatía isquémica revascularizada: IAM apical Killip III (mayo 2009), con regreso el mes de junio del mismo año por angor post-IAM, realizándose cateterismo y ACTP a DA con stent farmacoactivo y ACTP a OM1 (intentando implantación de stent sin éxito).
# PRUEBA DE ESFUERZO (30/08/2010): Prueba de sobrecarga farmacológica con dipiridamol clínicamente negativa y eléctricamente no valorable para isquemia miocárdica. Pendiente de realización de SPECT de perfusión miocárdica (protocolo largo) para completar el estudio.
# ÚLTIMO ECOCARDIOGRAMA (mayo 2010):
# Insuficiencia mitral moderada con "jet" excéntrico, velos discretamente engrosados y restricción de la valva posterior. Ventrículo izquierdo ligeramente hipertrófico con motilidad global moderadamente reducida por hipocinesia difusa con marcado movimiento anómalo del septum. Patrón diastólico de alteración de la relajación. Esclerosis aórtica sin disfunción valvular. Ligera dilatación de la aurícula izquierda.
# Ventrículo derecho normocontràctil. No se detecta derrame pericárdico.
# 5. Obesidad grado I (IMC 32).
# 6. FIBRILACIÓN AURICULAR PAROXÍSTICA en tratamiento frenador. En seguimiento por Cardiología, se decidió no anticoagular.
# ***IQ: cesárea (x2), amigdalectomía.
# ***MEDICACIÓN HABITUAL
# - Insulina rápida 10 UI en las comidas con variaciones según necesidades. - Insulina glargina 32UI 18-0-14 - Cefditoreno 200mg c/12h
# - Omeprazol 20mg c/24h - Salbutamol 100mcg 2inh c/8h - AAS 100mg c/24h - Amiodarona 200mg 5 comprimidos c/7d - Mononitrato de isosorbida 50mg 24h - Nitroglicerina + Cafeína si precisa - Furosemida 40mg C712h - Atorvastatina 10mg c/24h - Paracetamol 500mg si precisa - Acido Micofenolico 180mg c/12h - Tacrolimus 0,5mg (0-0-1) - Bisoprolol 1,25mg 24h - Acetilcisteína 600mg c/24h.
#
#
#
#
# ======================
# ======================
# ANTECEDENTES PERSONALES
# Varón de 33 años natural de Sierra Leona, refiere reacción cutánea en una ocasión a la administración de penicilina.
# No antecedentes médicos relevantes.
# No toma medicación habitual.
# Situacion social: Hermana trabajador de clínica veterinaria afecta de COVID19.
#
#
#
# ======================
# ======================
# Mujer de 41 años, trabaja como directora de operaciones en la industria textil. Natural de Bélgica, vive en Renedo de Valdavia con esposo y 2 yernos. No alergias medicamentosas ni hábitos tóxicos.
# ** ANTECEDENTES PATOLÓGICOS
# 1. RINITIS ALÉRGICA con manejo sintomático.
# 2. MIGRAÑA no complicada, en tratamiento abortivo con Ibuprofeno si precisa.
# ** ANTECEDENTES QUIRÚRGICOS
# 1. Colecistectomía por Colecistitis Aguda en Mar/2014
# ** MEDICACIÓN HABITUAL 17/11/2017: Niega medicación habitual, sólo uso ocasional de Cetirizina e Ibuprofeno.
#
#
#
# ======================
# ======================
# Antecedentes personales:
# Mujer de 46 años, sin alergias médicas conocidas. Natural de Isla Niue.
# **ANTECEDENTES PATOLÓGICOS:
# 1. Infecciones urinarias de repetición
# 2. Prolapaso de vávula mitral diagnósticada hace 10 años. Sin tratamiento
# 3. Bursitis de tobillo derecho. En tratamiento análegsico
# 4. Lumbalgía mecánica
# **MEDICACIÓN HABITUAL: niega.
#
#
#
#
# ======================
# ======================
# ANTECEDENTS PERSONALS:
# Sense alèrgies medicamentoses
# Exfumador des de fa 30 anys.
# - Hipertensió arterial en tractament farmacològic amb IECAs i betabloquejant.
# - Dislipemia en tractament amb estatines.
# - Hiperuricèmia en tractament amb Alopurinol. Ha presentat diverses crisis gotoses.
# - Enfisema centrelobulillar lleu detectat a TC toràcic 2014 arrel de tos persistent. En TC 2014 es va objectivar la
# presència de tres imatges nodulars basals i perifèriques a parènquima pulmonar, una a si costofrènic dret de 8mm
# i dos a base esquerra de 8 i 5mm, no visualitzades a TC previ (2011), que podien trobar-se en relació a
# sobreinfecció respiratòria vs imatges residuals d'un procés inflamatori.
# Al TC tòrax control 2015 es va observar una
# resolució de les imatges.
# - Aneurisme d'aorta descendent diagnosticat l'any 2014 mitjançant TC toràcic, inicialment de 38mm, objectivant-se al TC de control (mayo 2018) augment del tamany fins a 44x35mm màxim, sense progressió al control de gener 2019.
# - Tremolor essencial que ha rebut terapia recient amb HIFU al agost de 2022 a l'Cl. Costa de la Luz.
# - Cardiopatia isquèmica en forma de per IAMSEST Killip I al 2018.
# Ecocardiograma amb FEVE conservada i hipocinèsia inferior basal. Es va realitzar cateterisme cardíac que va mostrar malaltia de 2 vasos amb lesió severa i trombòtica en CX proximal que es va revascularitzar percutaneament amb implantació de stent a la CXp. FE 62%, motilitat 1 SPECT de perfusió miocàrdica necrosi no transmural inferolateral basal amb mínima isquèmia del mateix territori. El pacient segueix controls en cardiologia per VH. Ha presentat dispnea per ticagrelor i´clínica d'astènia i adinàmia en relació a betabloquejants.
# - Fibril.lació auricular revertida espontàniament al abril 2022, al alta es va iniciar anticoagulació amb NACO i control del ritme amb amiodarona. Es va retirar amiodarona al mayo de 2022. Al setembre de 2022 fibril·lació auricular i es va fer ecocardiograma transesofàgic que ha descartà la presència de trombos intracavitaris es va fer a la realització de cardioversió elèctrica sincronitzada passant a ritme sinusal estable i sense complicacions inmediates. Pendent de valorar ablaci ambulatòriamente per valorar anatomia de les venes pulmonars i valoració de ablació de VVPP ambulatòriament.
# - Tractament habitual:
# Omeprazol 20 mg 1 comprimit al dia en dejú abans d'esmorzar
# Adiro 100 mg 1 comprimit al dia a l'esmorzar
# Eliquis 5mg cada 12 hores
# Multaq 400 mg 1 comprimit cada 12 hores
# Bisoprolol 2.5 mg 1 comprimit al dia a l'esmorzar
# Enalapril 20 mg 1 comprimit al dia a l'esmorzar
# Zyloric 100 mg 1 comprimit al dia
# Atorvastatina 40 mg 1 comprimit al dia al sopar.
#
#
#
#
# ======================
# ======================
# Antecedentes personales:
# Natural de Islas Falkland (Malvinas), siempre ha vivido en zona urbana y posiblemente periurbana pero sí que ha vivido en casa de caña de pequeño, posible vacunación de fiebre amarilla hace 4 años (lo vacuranon para salir del país), puede que también de hepatitis pero no lo recuerda, en historia compartida: DT 2012 y VHB 2006, nunca ha tenido dengue ni malaria, no ha tenido hepatitis, conoce la enfermedad de Chagas pero no conoce a nadie que ha tenido la enfermedad, no historia personal ni familiar de tuberculosis.
# Vive con su cuñado en domicilio
# No tabaquismo ni consumo de tóxicos. Ex-enolismo (desde 2017, consumo enólico ocasional (refiere 4 cervezas al mes, pero aumento de consumo periódico).
# 1.-EPILEPSIA EN TRATAMIENTO CON DEPAKINE (desde 2012) .
# 2.-HTA en tratamiento con IECA y ACA
# .
# 3.-OBESIDAD
# .
# 4.- HÍGADO GRASO MULTIFACTORIAL (disfunción metabólica asociada a la enfermedad por hígado graso(MAFLD)) CON POSIBLE COMPONENTE FARMACOLÓGICO (VALPROATO) Y -OH
# .
# 5.- HBP EN TRATAMIENTO CON UROREC.
# .
# Medicación habitual: TRATAMIENTO (23/ 6): . - DEPAKINE 500: 1 COMP CADA 8 HORAS . - LISINOPRIL 20MG: 1 COMP E N DESAYUNO . - AMLODIPINO 5MG: 1 COMP CADA 24 H . - UROREC 4MG: 1 COMP C ADA 24 HORAS.
#
#
#
#
# ======================
# ======================
# Hombre de 63 años de edad, sin alergias medicamentosas conocidas.
# Exfumador de 10 cigarrillos/día hasta hace unos 10 años. Sin otros hábitos tóxicos en el momento actual.
# ANTECEDENTES PERSONALES:
# 1. LINFOMA B DE ALTO GRADO tratado con quimioterapia hasta enero de2017. En remisión completa metabólica desde 01/2011. En seguimiento por el Hospital de día de Hematología.
# * R-CHP x5. Último el 01/2011.
# * PET-TC (11/5/2011): remisión completa metabólica.
# * Último TC toracoabdominal (12/11): sin signos síndrome linfoproliferativo
# --> COMPLICACIONES
# Como complicación de la administración de metotrexate intatecal desarrolló una paraparesia y vegija neurógena. Desde entonces presenta infecciones urinarias de repetición. (Octubre 2012 ITU por p.aeruginosa multiresistente)
# 2. POLIRRADICULOPATÍA LUMBOSACRA con paresia EEII e incontinencia esfinteriana secundaria a MTX IT Hipoestesia-anestesia desde T4 hasta miembros inferiores sin mejoría clínica.
# 3. INFECCIÓN POR VIH, diagnosticada en el 1986. Realiza segumiento en Infecciones del Los Naranjos con buen control. Nadir de CD4 de 16.
# Última carga viral indetectable.
# *Infecciones oportunistas: neumonía por P. jirovecii (1989), tuberculosis diseminada (fiebre prolongada + adenopatías) que se trató con tratamiento antituberculoso empírico.
# 4. TROMBOFILIA con un factor de V Leiden heterozigoto y déficit de proteina S. Trombosis venosa profunda de repetición. Actualmente en tratamiento con edoxaban 30mg/dia.
# 5. ICTUS ISQUÉMICO EN EL TERRITORIO DE LA ARTERIA CEREBRAL POSTERIOR IZQUIERDA (ACPI) DE CAUSA INDETERMINADA (ESTUDIO INCOMPLETO). Inició AAS.
# 6. INSUFICIENCIA RENAL CRONICA. Filtrado glomerural alrededor de 50 ml/min
# 7. INFECCIONES URINARIAS de repetición en contexto de autosondajes.
# Actualmente en sondaje vesical permanente. Aislamiento en 2010 P.aeruginosa multiR (posteriormente sensibleS) y en el último año K.pneumoniae BLEA y P.mirabilis BLEA.
# MEDICACIÓN HABITUAL: Rilpivirina 25mg/24h; Emtricitabina/Tenofovir 200/25mg/24h; Dolutegravir50mg/12h; Cotrimoxazol forte L-X-V; Acido fólico 5 mg/día; Lactulosa 15 ml con la comida; Edoxaban 30mg/24h; AAS 100mg/24h; Betmiga 50mg/24h;   Podofilotoxina; Enalapril 5mg.
#
#
#
# ======================
# ======================
# Vive en residencia, cognitivamente preservada, es capaz de asearse ella sola y comer sola, Barthel 55.
# Alergica a anestesicos locales, propofol. Antibióticos: Ceftibuteno, tetraciclinas, ciprofloxacino, cotrimoxazol, eritromicina, estreptomicina, fosfomicina, vancomicina y linezolid. No ha presentado alergia a: Teicoplanina, aztreonam, furantoina y
# amoxicilina/calvulanico.
# ANTECEDENTES PATOLÓGICOS:
# 1. Hipertensión arterial en tratamiento farmacológico.
# 2. Fibrilación auricular crónica en tratamiento frenador y anticoagulada con dabigatran.
# 3. Dislipemia en tratamiento
# 4. ACMD de etiología cardioembólica que condiciona hemiparesia izquierda residual.
# 5. Retinosis pigmentaria.
# Medicación habitual 4/11/2020:
# Dabigatran 110 mg/12h Omeprazol 20 mg/24h Tofranil 25 mg Bis oproplol 2.5-0-5 Digoxina 0.25 mg Lu-Mi-Vi Atorvastatina 20 mg/24h Secal ip 145 mg lunes-mi-Vi Osteopor 830 mg/24h Lormetazepam 1 mg/24h Paracetamol 500 mg SP.
#
#
#
#
# ======================
# ======================
# Varón de 61 años, sin alergias medicamentosas conocidas. No hábitos tóxicos. Vive en Arias con su marido y un hijo (tiene 2 yernos, abuelo vive fuera de Arias). IABVD. Autónomo, actualmente preocupado por situación laboral (realizaba trabajo como terapeuta deportivo).
# * ANTECEDENTES FAMILIARES: No refiere.
# * ANTECEDENTES PATOLÓGICOS:
# 1.- DISLIPEMIA en tratamiento con Atorvastatina.
# 2.- HERNIA DE HIATO diagnosticada hace años. Desde hace aproximádamente un mes (Febrero-Marzo), refiere comienzo de Omeprazol cada día por dolor epigástrico que ha aumentado en frecuencia.
# 3.- DOLOR TORÁCICO EN ESTUDIO. Desde hace aproximádamente un año (mediados de 2020) refiere inicio de dolor torácico punzante de forma intermitente, no relacionado con esfuerzo, sin cortejo vegetativo ni disnea, no irradiado y que no empeora con los movimientos respiratorios aunque sí se modifica con los cambios posturales. Respuesta parcial a AINEs (Naproxeno), no se modifica con el Omeprazol. Se ha realizado estudio mediante ECGs previos y Radiografía de tórax donde no se han evidenciado alteraciones. No tiene prueba de esfuerzo ni estudio Holter o ecocardiograma.
# 4.- TRASTORNO ANSIOSO-DEPRESIVO en tratamiento con Alprazolam a demanda (2 comprimidos al día aproximádamente) por situación laboral actual en contexto de pandemia de Covid-19.
# * ANTECEDENTES QUIRÚRGICOS: No refiere.
# * MEDICACIÓN HABITUAL (actualizada a fecha de 25/11/2021): Omeprazol 20 mg/24h, Atorvastatina 40 mg/24 horas.
#
#
#
# ======================
# ======================
# Hombre de 57 años. No alergias medicamentosas conocidas. Exfumador hasta diciembre del 2020 (fumaba 40 cig/día). Natural de Siria. Vive en Valga con su hermano y dos hijos. No barrera idiomática.
# * ANTECEDENTES PATOLÓGICOS:
# - ICTUS DE LA BASILAR, el 17/5/21, trombectomía mecanica TICI3, sin secuelas.
# - RADICULOPATIA SACRA Y HERNIAS DISCALES
# RMN 17/5/21: Discopatia y discretos cambios degenerativos en las articulaciones interapofisarias en L2-L3, L3-L4 y L4-L5, en los tres niveles con protrusiones discales generalizadas que a nivel posterior contactan y rectifican el margen anterior del saco dural, reducen discretamente el diametro A-P del canal central y estenosan sus recesos laterales. Discreta reduccion de los calibres de sus orificios.
# En L5-S1 se aprecia una pequeña herniacion discal de base amplia en situacion paramediana izquierda que establece contacto con la raiz S1 izquierda emergente en el canal central.
# Por dolor persistente en EEII izquierda sugestivo de radiculopatía S1 se solicita RM lumbar que confirma hernia discal a nivel L5-S1 que comprime a S1 y estenosis de canal lumbar con mal control del dolor. Gammagrafía ósea descarta progresión de la enfermedad.
# - POSIBLE EPOC sin PFR
# - CARCINOMA UROTELIAL LOCALMENTE AVANZADO
# Diagnostico en septiembre de 2020 por hematuria.
# Se remitió inicialmente a Centro Médico Aspasia para valorar quimioterapia neodadyuvante que se desestimó por hidronefrosis bilateral, el 01/04 se realizó nefrostomía derecha (hidronefrosis bilateral con anulación de riñón izquierdo y retraso en la eliminación de contraste del derecho). Posteriormente se revaloró en urología de nuestro centro desestimando tratamiento quirúrgico y derivando el caso a oncología para tratamiento sistémico con eventual rescate quirúrgico.
# >> TC (diciembre/2020): Gran tumoración en hemivejiga izquierda que presenta signos de importante infiltración local, con adenopatía necrótica ilíaca interna izquierda, atrapamiento de uréter izquierdo. Contacto extenso próstata. La adenopatía izquierda rodea arteria hipogástrica. Signos de infiltración de músculo obturador interno. No M1 a distancia.
# Tratamientos y evolución:
# Inicia tratamiento neoadyuvantye con Cisplatino - gemcitabina. C1 2/2/21, C4 14/7/21
# Revalorado en comité de tumores urologicos, TC con clara disminución de la masa vesical y se identifica una adenopatia necrótica obturatriz izquierda de gran tamaño. Se decide realizar una exeresis compleja abierta y posterior radioterapia de rescate.
# Cirugía: CISTOPROSTATECTOMIA RADICAL ABIERTA CON DERIVACIÓN ILEAL TIPO BRICKER+ LINFADENECTOMIAILEOOBTURATRIZ BILATERAL (IQ 27/6/2021).
# No se consiguió R0 debido a presencia de infiltración adenopática presacra y del nervio obsturador que se lesionó. AP en curso.
# * Seguimiento en Oncología Médica (Dra. Garikoitz)
# - SHOCK SÉPTICO DE FOCO URINARIO. BACTERIEMIA POR KLEBSIELLA PNEUMONIAE en contexto de NEUTROPENIA FEBRIL DE RIESGO ALTO. ÚLTIMO CICLO DE QUIMOTERAPIA 18/04, requirió ingreso en UCI con DVA, también IRA AKIN II prerrenal.
# - TROMBOEMBOLISMO PULMONAR BILATERAL (LOBAR IZQ, SEGMENTARIO LSI, SUBSEGMENTARIO LII + SEGMENTARIO LID) en ingreso de abril 2021 con TROMBOPENIA INDUCIDA POR HEPARINA con positividad de anticuerpos anti PD-4 requirió al principio colocación de filtro de vena cava.
# Actualmente con anticoagulante de forma indefinida por haber presentado dos episodios tromboembólicos atribuibles a patología neoplásica.
# * TRATAMIENTO HABITUAL (6/2021): metoclopramida 10mg/8h, omeprazol 20mg/d, ondansetrón 4mg/8h, MST 60 mg/12h, Sevredol 10 mg/4h de rescate.
# Pregabalina 100 mg/12h y Movicol 1s/8h. Clonazepam 0,5 mg/noche y Naloxegol 25 mg/día.
#
#
#
#
# ======================

# %%
print('recall avg',np.mean(df2['recall']))
print('precision avg',np.mean(df2['precision']))
print('f1 avg',np.mean(df2['f1']))

df2['masked_count'] = df2['Masked'].str.count(r'\[\*\*')
total_masked_count=np.sum(df2['masked_count'])
total_recall=0
total_precision=0
total_f1=0
for i in range(len(df2)):
    total_recall+=df2['recall'][i]*df2['masked_count'][i]
    total_precision+=df2['precision'][i]*df2['masked_count'][i]
    total_f1+=df2['f1'][i]*df2['masked_count'][i]
recall_weighted_avg = total_recall/total_masked_count
precision_weighted_avg = total_precision/total_masked_count
f1_weighted_avg = total_f1/total_masked_count
print('recall weighted avg',recall_weighted_avg)
print('precision weighted avg',precision_weighted_avg)
print('f1 weightedavg',f1_weighted_avg)
# Out:
# recall avg 0.9544971797541664
# precision avg 0.9048576421661341
# f1 avg 0.9232730179310334
# recall weighted avg 0.9494918817895105
# precision weighted avg 0.9231142353168734
# f1 weightedavg 0.9328754438081449

# %%
df2.to_csv('20240810_CARMEN_Results.csv',index=False,encoding='utf-8')

# %%
df2=pd.read_csv('20240810_CARMEN_Results.csv',encoding='utf-8')
sample_size=len(df2)
print(len(df2))
# Out:
# 100

# %%
FN_category_dfs
# Out:
#                         category   FN_count  target_count
# 0                          CALLE   0.000000             0
# 1                   CENTRO_SALUD   0.000000             4
# 2         EDAD_SUJETO_ASISTENCIA   0.000000            96
# 3   FAMILIARES_SUJETO_ASISTENCIA  10.600000            99
# 4                         FECHAS  34.866667           709
# 5                       HOSPITAL   3.250000            67
# 6        ID_CONTACTO_ASISTENCIAL   0.000000             0
# 7           ID_SUJETO_ASISTENCIA   0.000000             4
# 8                    INSTITUCION   1.000000             7
# 9      NOMBRE_PERSONAL_SANITARIO   1.000000            29
# 10                NUMERO_IDENTIF   1.000000             2
# 11               NUMERO_TELEFONO   0.000000             4
# 12       OTROS_SUJETO_ASISTENCIA   2.000000             2
# 13                          PAIS   3.000000            55
# 14                     PROFESION   5.054762            37
# 15        SEXO_SUJETO_ASISTENCIA   0.000000            69
# 16                    TERRITORIO   0.000000            39
# 17                       URL_WEB   0.000000             0

# %% [markdown]
# # Veiwing examples

# %%
a-20
print('recall',df2['recall'][a])
print('precision',df2['precision'][a])
print(df2['Masked'][a])
# Out:
# recall 1.0
# precision 1.0
# Antecedentes personales:
# [**Mujer**] de [**49 años**], alérgica al ácido acetilsalicílico, sulfamidas, sulfametoxazol/trometoprim, amoxicilina/clavulánico (rash cutáneo) e hipersensibilidad al abacavir.
# Fumadora actual de 3 cig/día, previamente 2-3 paq/día con dosis acumulada de 50 paq/año, no bebedora de alcohol. Consumidora esporádica de cocaína y metanfetamina inhalada, no UDVP. ndependiente para las actividades básicas de la vida diaria, vive en la calle en situación de indigencia.
# ANTECEDENTES PATOLÓGICOS:
# 1. INFECCIÓN POR VIH ESTADIO C3 diagnosticada en [**1990**], adquirida por contacto sexual. Controlada previamente en [**H. Universitario Federico García Lorca**] de [**1990**]-[**1991**], realiza seguimiento en nuestro hospital desde [**dic/05**].
# * Control [**may/12**] CD4 4 cél/ul, carga viral VIH 1 754,000 cp/ml.
# * Serología IgG VHA +, HBsAg -, IgG VHB +, IgG VHC -, IgG CMV +, VRDL -, IgG toxoplasma +, IgG sarampión +, Ac rubéola +, Ac VVZ +, PPD -.
# * HLA-FG B5701 [**dic/6**] +.
# * Tratamiento con mala adherencia, desde [**mar/12**] correcto cumplimiento.
# - [**25/12**]-[**26/12**]: abacavir/lamivudina + ritonavir + atazanavir.
# - [**26/12**]-[**28/02**]: emtricitabina/tenofovir + ritonavir + atazanavir.
# - [**28/02**]-[**27/03**]: emtricitabina/tenofovir + raltegravir.
# - [**28/03**]-[**30/03**]: lamivudina.
# - [**30/03**]-[**3/04**]: etravirina + darunavir + maraviroc + ritonavir.
# - [**3/04**]-[**12/6**]: darunavir + emtricitabina/tenofovir + ritonavir.
# - [**12/6**]-[**03/9**]: darunavir + emtricitabina/tenofovir + ritonavir.
# - [**03/9**]-[**09/10**]: elvitegravir/cobicistat/TAF/emtricitabina.
# - [**09/10**]-[**02/12**]: darunavir/cobicistat + emtricitabina/TAF.
# - [**02/12**]-actual: darunavir/cobicistat/emtricitabina/TAF.
# * Pielonefritis bilateral por K. pneumoniae y S. aureus, neumonía adquirida en la comunidad e hipopotasemia/hipocalcemia en [**jun/12**].
# * Infecciones oportunistas:
# - BACTERIANAS: ITUs de repetición ([**may/12**] en dos ocasiones K. pneumoniae resistente a ampicilina, ciprofloxacino y fosfomicina tratada con cefixima, [**mar/12**] sin aislamientos tratamiento con ertapenem, ecografía sin alteraciones, [**ene/12**] E. coli productor de cefaciminasa, [**ene/10**] E. coli multisensible). Neumonías de repetición por K. pneumoniae en [**2010**] y neumococo en [**ene/12**].
# - FÚNGICAS: neumonía por P. jirovecii en [**dic/05**], [**mar/08**] y [**oct/11**], tratamiento inicial con cotrimoxazol pero ante rash eritematoso se continuó con atovacuona, realizó profilaxis secundaria con pentamidina nebulizada que abandonó, posteriormente con atovacuona (mala adherencia) y desde [**may/12**] dapsona y pirimetamina. Múltiples episodios de candidiasis oral, la última en [**dic/11**].
# - VIRALES: herpes zóster en muslo derecho en [**2001**] y en extremidad inferior izquierda en [**2011**] tratada con valaciclovir, VHS esofágico en [**2010**] por lo que recibió aciclovir.
# 2. ANEMIA NORMOCÍTICA-NORMOCRÓMICA presente de manera crónica.
# 3. TROMBOSIS VENOSA PROFUNDA de extremidad superior derecha en [**1998**], tratada previamente con acenocumarol, actualmente sin anticoagulación.
# 4. PANCREATITIS AGUDA e íleo secundario en [**2009**].
# 5. FRACTURA DE AMBOS ANTEBRAZOS tras caída en [**1989**] (sin informes).
# 6. TRAUMATISMO CRANEOENCEFÁLICO en tres ocasiones.
# 7. ANTECEDENTES OBSTÉTRICOS 3 embarazos a término, 8 abortos electivos.
# 8. BICITOPENIA (leucopenia-neutropenia y anemia macrocítica) desde [**2009**] posiblemente en contexto de displasia asociada a VIH avanzado y déficit de factores madurativos, suplementado con ácido fólico. * Mielograma [**mar/12**] compatible con déficit de factores de maduración vs mielodisplasia, sin atipias celulares, cultivos negativos.
# 9. PTOSIS OJO IZQUIERDO detectada en [**mar/11**], no seguimiento.
# MEDICACIÓN HABITUAL: enalapril 2.5 mg c/24 h, ipratropio 20 mcg 1 INH c/8 h, tiamina/piridoxina/cianocobalamina 1 comp c/24 h, ácido folínico 15 mg c/72 h, pirimetamina 25 mg c/72 h.
# TRATAMIENTO ANTIRETROVIRAL: darunavir/covicistat/tenofovir/emtricitabina 800/150/10/200 mg c/24 h.
# PROFILAXIS PRIMARIA PCP: dapsona 100 mg, pirimetamina 25 mg y lederfolin 15 mg cada lunes y jueves.

# %%
print(df2['Prediction_processed'][a])
# Out:
# Antecedentes personales:
# [**Mujer**] de [**49 años**], alérgica al ácido acetilsalicílico, sulfamidas, sulfametoxazol/trometoprim, amoxicilina/clavulánico (rash cutáneo) e hipersensibilidad al abacavir.
# Fumadora actual de 3 cig/día, previamente 2-3 paq/día con dosis acumulada de 50 paq/año, no bebedora de alcohol. Consumidora esporádica de cocaína y metanfetamina inhalada, no UDVP. ndependiente para las actividades básicas de la vida diaria, vive en la calle en situación de indigencia.
# ANTECEDENTES PATOLÓGICOS:
# 1. INFECCIÓN POR VIH ESTADIO C3 diagnosticada en [**1990**], adquirida por contacto sexual. Controlada previamente en [**H. Universitario Federico García Lorca**] de [**1990-1991**], realiza seguimiento en nuestro hospital desde [**dic/05**].
# * Control [**may/12**] CD4 4 cél/ul, carga viral VIH 1 754,000 cp/ml.
# * Serología IgG VHA +, HBsAg -, IgG VHB +, IgG VHC -, IgG CMV +, VRDL -, IgG toxoplasma +, IgG sarampión +, Ac rubéola +, Ac VVZ +, PPD -.
# * HLA-FG B5701 [**dic/6**] +.
# * Tratamiento con mala adherencia, desde [**mar/12**] correcto cumplimiento.
# - [**25/12**]-[**26/12**]: abacavir/lamivudina + ritonavir + atazanavir.
# - [**26/12**]-[**28/02**]: emtricitabina/tenofovir + ritonavir + atazanavir.
# - [**28/02**]-[**27/03**]: emtricitabina/tenofovir + raltegravir.
# - [**28/03**]-[**30/03**]: lamivudina.
# - [**30/03**]-[**3/04**]: etravirina + darunavir + maraviroc + ritonavir.
# - [**3/04**]-[**12/6**]: darunavir + emtricitabina/tenofovir + ritonavir.
# - [**12/6**]-[**03/9**]: darunavir + emtricitabina/tenofovir + ritonavir.
# - [**03/9**]-[**09/10**]: elvitegravir/cobicistat/TAF/emtricitabina.
# - [**09/10**]-[**02/12**]: darunavir/cobicistat + emtricitabina/TAF.
# - [**02/12**]-actual: darunavir/cobicistat/emtricitabina/TAF.
# * Pielonefritis bilateral por K. pneumoniae y S. aureus, neumonía adquirida en la comunidad e hipopotasemia/hipocalcemia en [**jun/12**].
# * Infecciones oportunistas:
# - BACTERIANAS: ITUs de repetición ([**may/12**] en dos ocasiones K. pneumoniae resistente a ampicilina, ciprofloxacino y fosfomicina tratada con cefixima, [**mar/12**] sin aislamientos tratamiento con ertapenem, ecografía sin alteraciones, [**ene/12**] E. coli productor de cefaciminasa, [**ene/10**] E. coli multisensible). Neumonías de repetición por K. pneumoniae en [**2010**] y neumococo en [**ene/12**].
# - FÚNGICAS: neumonía por P. jirovecii en [**dic/05**], [**mar/08**] y [**oct/11**], tratamiento inicial con cotrimoxazol pero ante rash eritematoso se continuó con atovacuona, realizó profilaxis secundaria con pentamidina nebulizada que abandonó, posteriormente con atovacuona (mala adherencia) y desde [**may/12**] dapsona y pirimetamina. Múltiples episodios de candidiasis oral, la última en [**dic/11**].
# - VIRALES: herpes zóster en muslo derecho en [**2001**] y en extremidad inferior izquierda en [**2011**] tratada con valaciclovir, VHS esofágico en [**2010**] por lo que recibió aciclovir.
# 2. ANEMIA NORMOCÍTICA-NORMOCRÓMICA presente de manera crónica.
# 3. TROMBOSIS VENOSA PROFUNDA de extremidad superior derecha en [**1998**], tratada previamente con acenocumarol, actualmente sin anticoagulación.
# 4. PANCREATITIS AGUDA e íleo secundario en [**2009**].
# 5. FRACTURA DE AMBOS ANTEBRAZOS tras caída en [**1989**] (sin informes).
# 6. TRAUMATISMO CRANEOENCEFÁLICO en tres ocasiones.
# 7. ANTECEDENTES OBSTÉTRICOS 3 embarazos a término, 8 abortos electivos.
# 8. BICITOPENIA (leucopenia-neutropenia y anemia macrocítica) desde [**2009**] posiblemente en contexto de displasia asociada a VIH avanzado y déficit de factores madurativos, suplementado con ácido fólico. * Mielograma [**mar/12**] compatible con déficit de factores de maduración vs mielodisplasia, sin atipias celulares, cultivos negativos.
# 9. PTOSIS OJO IZQUIERDO detectada en [**mar/11**], no seguimiento.
# MEDICACIÓN HABITUAL: enalapril 2.5 mg c/24 h, ipratropio 20 mcg 1 INH c/8 h, tiamina/piridoxina/cianocobalamina 1 comp c/24 h, ácido folínico 15 mg c/72 h, pirimetamina 25 mg c/72 h.
# TRATAMIENTO ANTIRETROVIRAL: darunavir/covicistat/tenofovir/emtricitabina 800/150/10/200 mg c/24 h.
# PROFILAXIS PRIMARIA PCP: dapsona 100 mg, pirimetamina 25 mg y lederfolin 15 mg cada lunes y jueves.

# %%
masked=df2['Masked'][a]
generated=df2['Prediction_processed'][a]

# %%
masked=masked.replace('\n','')
generated=generated.replace('\n','')

ground_truth_matches = re.finditer(r'\[\*\*(.*?)\*\*\]', masked)
ground_truth_positions = {}
cnt=0
for match in ground_truth_matches:
    start = match.start(1)-(cnt*2+1)*3  # start of the group (excluding [**)
    end = match.end(1)-(cnt*2+1)*3
    cnt+=1# end of the group (excluding **])
    ground_truth_positions[(start, end)] = replace_special_characters(match.group(1))

predictions_matches = re.finditer(r'\[\*\*(.*?)\*\*\]', generated)
predictions_positions = {}
cnt=0
for match in predictions_matches:
    start = match.start(1)-(cnt*2+1)*3  # start of the group (excluding [**)
    end = match.end(1)-(cnt*2+1)*3
    cnt+=1# end of the group (excluding **])
    predictions_positions[(start, end)] = replace_special_characters(match.group(1))

totalwordcnt_ground_truth = len(ground_truth_positions)
score_total=0
for pos_g in ground_truth_positions:
    for pos_p in predictions_positions:
        if (pos_p[0]<=pos_g[0] and pos_p[1]>=pos_g[1]) or (pos_p[0]>=pos_g[0] and pos_p[1]<=pos_g[1]):
            score_temp = partial_score(ground_truth_positions[pos_g],predictions_positions[pos_p])
            score_total += score_temp
            print(score_temp,ground_truth_positions[pos_g])

score_total = score_total/totalwordcnt_ground_truth
recall = score_total

totalwordcnt_predictions = len(predictions_positions)
score_total=0
for pos_p in predictions_positions:
    for pos_g in ground_truth_positions:
        if (pos_g[0]<=pos_p[0] and pos_g[1]>=pos_p[1]) or (pos_g[0]>=pos_p[0] and pos_g[1]<=pos_p[1]):
            score_temp = partial_score(predictions_positions[pos_p],ground_truth_positions[pos_g])
            score_total += score_temp

score_total = score_total/totalwordcnt_predictions
precision = score_total

f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
# Out:
# 1.0 Mujer
# 1.0 49 años
# 1.0 1990
# 1.0 H  Universitario Federico García Lorca
# 1.0 1990
# 1.0 1991
# 1.0 dic 05
# 1.0 may 12
# 1.0 dic 6
# 1.0 mar 12
# 1.0 25 12
# 1.0 26 12
# 1.0 26 12
# 1.0 28 02
# 1.0 28 02
# 1.0 27 03
# 1.0 28 03
# 1.0 30 03
# 1.0 30 03
# 1.0 3 04
# 1.0 3 04
# 1.0 12 6
# 1.0 12 6
# 1.0 03 9
# 1.0 03 9
# 1.0 09 10
# 1.0 09 10
# 1.0 02 12
# 1.0 02 12
# 1.0 jun 12
# 1.0 may 12
# 1.0 mar 12
# 1.0 ene 12
# 1.0 ene 10
# 1.0 2010
# 1.0 ene 12
# 1.0 dic 05
# 1.0 mar 08
# 1.0 oct 11
# 1.0 may 12
# 1.0 dic 11
# 1.0 2001
# 1.0 2011
# 1.0 2010
# 1.0 1998
# 1.0 2009
# 1.0 1989
# 1.0 2009
# 1.0 mar 12
# 1.0 mar 11

# %%
ground_truth_positions
# Out:
# {(24, 29): 'Mujer',
#  (33, 40): '49 años',
#  (550, 554): '1990',
#  (613, 651): 'H  Universitario Federico García Lorca',
#  (655, 659): '1990',
#  (660, 664): '1991',
#  (712, 718): 'dic 05',
#  (729, 735): 'may 12',
#  (935, 940): 'dic 6',
#  (984, 990): 'mar 12',
#  (1015, 1020): '25 12',
#  (1021, 1026): '26 12',
#  (1075, 1080): '26 12',
#  (1081, 1086): '28 02',
#  (1139, 1144): '28 02',
#  (1145, 1150): '27 03',
#  (1192, 1197): '28 03',
#  (1198, 1203): '30 03',
#  (1218, 1223): '30 03',
#  (1224, 1228): '3 04',
#  (1279, 1283): '3 04',
#  (1284, 1288): '12 6',
#  (1340, 1344): '12 6',
#  (1345, 1349): '03 9',
#  (1401, 1405): '03 9',
#  (1406, 1411): '09 10',
#  (1457, 1462): '09 10',
#  (1463, 1468): '02 12',
#  (1513, 1518): '02 12',
#  (1690, 1696): 'jun 12',
#  (1759, 1765): 'may 12',
#  (1873, 1879): 'mar 12',
#  (1952, 1958): 'ene 12',
#  (1994, 2000): 'ene 10',
#  (2070, 2074): '2010',
#  (2090, 2096): 'ene 12',
#  (2138, 2144): 'dic 05',
#  (2146, 2152): 'mar 08',
#  (2155, 2161): 'oct 11',
#  (2382, 2388): 'may 12',
#  (2467, 2473): 'dic 11',
#  (2519, 2523): '2001',
#  (2562, 2566): '2011',
#  (2610, 2614): '2010',
#  (2769, 2773): '1998',
#  (2888, 2892): '2009',
#  (2939, 2943): '1989',
#  (3147, 3151): '2009',
#  (3293, 3299): 'mar 12',
#  (3447, 3453): 'mar 11'}

# %%
predictions_positions
# Out:
# {(24, 29): 'Mujer',
#  (33, 40): '49 años',
#  (550, 554): '1990',
#  (613, 651): 'H  Universitario Federico García Lorca',
#  (655, 664): '1990 1991',
#  (712, 718): 'dic 05',
#  (729, 735): 'may 12',
#  (935, 940): 'dic 6',
#  (984, 990): 'mar 12',
#  (1015, 1020): '25 12',
#  (1021, 1026): '26 12',
#  (1075, 1080): '26 12',
#  (1081, 1086): '28 02',
#  (1139, 1144): '28 02',
#  (1145, 1150): '27 03',
#  (1192, 1197): '28 03',
#  (1198, 1203): '30 03',
#  (1218, 1223): '30 03',
#  (1224, 1228): '3 04',
#  (1279, 1283): '3 04',
#  (1284, 1288): '12 6',
#  (1340, 1344): '12 6',
#  (1345, 1349): '03 9',
#  (1401, 1405): '03 9',
#  (1406, 1411): '09 10',
#  (1457, 1462): '09 10',
#  (1463, 1468): '02 12',
#  (1513, 1518): '02 12',
#  (1690, 1696): 'jun 12',
#  (1759, 1765): 'may 12',
#  (1873, 1879): 'mar 12',
#  (1952, 1958): 'ene 12',
#  (1994, 2000): 'ene 10',
#  (2070, 2074): '2010',
#  (2090, 2096): 'ene 12',
#  (2138, 2144): 'dic 05',
#  (2146, 2152): 'mar 08',
#  (2155, 2161): 'oct 11',
#  (2382, 2388): 'may 12',
#  (2467, 2473): 'dic 11',
#  (2519, 2523): '2001',
#  (2562, 2566): '2011',
#  (2610, 2614): '2010',
#  (2769, 2773): '1998',
#  (2888, 2892): '2009',
#  (2939, 2943): '1989',
#  (3147, 3151): '2009',
#  (3293, 3299): 'mar 12',
#  (3447, 3453): 'mar 11'}
